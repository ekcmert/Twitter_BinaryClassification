# %% [markdown]
# # 0. Initialize

# %% [markdown]
# ## 0.1. Import Libraries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os, sys, glob
import gzip
import random
import tqdm
import json
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)

from IPython import display
import matplotlib as mpl
from matplotlib import pyplot as plt

# %% [markdown]
# ## 0.2. DEFINE VARIABLES

# %%
DATA_PATH = '/Users/Gamegaraj/Desktop/CS412/data/' # '<insert-your-training-data-path-here>'

ROUND = 1 # This project will have 3 rounds of predictions: 1,2,3
STUDENT_ID = '26772'#'<insert-your-id-here>'
PROJECT_CODE = 'CS4129a709ea5dfc4'#'<insert-your-code-here>' # Same code for the annotation eg. CS412xxxxx

# %% [markdown]
# ## 0.3. Read Training & Evaluation Data

# %% [markdown]
# ### 0.3.1. Get the labels for tweets

# %%
#trainingTweetDf = pd.read_csv('{}training-tweet.csv'.format(DATA_PATH))
trainingTweetDf = pd.read_csv('{}training-tweet.csv'.format(DATA_PATH), dtype={'tweet_id': str, 'isPolitical': str})
trainingTweetDf
# Out:
#                  tweet_id isPolitical
# 0     1597170281545551872         Yes
# 1     1431700027471192069          No
# 2     1566035577090281472         Yes
# 3     1591538690869940225         Yes
# 4     1583898169238167554         Yes
# ...                   ...         ...
# 2995  1593539327623151619         Yes
# 2996  1393886554062524418          No
# 2997  1597925615092764672         Yes
# 2998  1585291418616176640         Yes
# 2999  1594775287622995971         Yes
#
# [3000 rows x 2 columns]

# %%
trainingTweetDf.isPolitical.value_counts()
# Out:
# Yes    2003
# No      997
# Name: isPolitical, dtype: int64

# %% [markdown]
# ### 0.3.2. Get the labels for users

# %%
trainingUserDf = pd.read_csv('{}training-user.csv'.format(DATA_PATH))
#trainingUserDf = pd.read_csv('training-user.csv')
trainingUserDf
# Out:
#           screen_name isBot
# 0       koftecancaddy    No
# 1              ahaber    No
# 2     selahat03949652    No
# 3       erdin06357062    No
# 4       bhct__necatii    No
# ...               ...   ...
# 2995     djblumenberg    No
# 2996           mel1sq    No
# 2997         eren_yz1   Yes
# 2998      ergnyildiz4    No
# 2999   isadal24978794   Yes
#
# [3000 rows x 2 columns]

# %% [markdown]
# ### 0.3.3. Expand your dataset with metadata and tweets

# %%
# You can also expand training data by downloading your own labeled datasets following the link
# Download the documents under "Link to training data"

#print('http://www.onurvarol.com/Annotation-CS412-202201/reports/report_{}.html'.format(PROJECT_CODE))
print('http://www.onurvarol.com/Annotation-CS412-202201/reports/report_{}.html'.format('CS412aa4c69f55b37'))
# Out:
# http://www.onurvarol.com/Annotation-CS412-202201/reports/report_CS412aa4c69f55b37.html

# %% [markdown]
# ### Add Annotation Data

# %%
codes = ['CS4129a709ea5dfc4','CS412a32e72d94b5f','CS412c255f188f1f1','CS4125691a2d1c16d','CS412aa4c69f55b37']

def mergeAnnotations(codes):
    df_users = pd.DataFrame()
    for i in codes:
        filename = 'annotated_users_{}.csv'.format(i)
        filename = ('{}'+filename)
        df = pd.read_csv(filename.format(DATA_PATH))
        df = df.drop(['url', 'isOrganizational', 'isTroll','gender'], axis=1)
        df = df.drop(df[df.isBot == 'Not sure'].index)
        df.rename(columns = {'Unnamed: 0':'screen_name'}, inplace = True)
        df.dropna(inplace=True)
        df_users = pd.concat([df,df_users])
    

    df_tweets = pd.DataFrame()
    for i in codes:
        filename = 'annotated_tweets_{}.csv'.format(i)
        filename = ('{}'+filename)
        df = pd.read_csv(filename.format(DATA_PATH))
        df = df.drop(['url', 'sentiment', 'isExperiential','isInsult','topics'], axis=1)
        df.rename(columns = {'Unnamed: 0':'tweet_id'}, inplace = True)
        df.dropna(inplace=True)
        df_tweets = pd.concat([df,df_tweets])  
        df_tweets['tweet_id'] = df_tweets['tweet_id'].astype(str)
    
    return df_users, df_tweets

# %%
df_users, df_tweets = mergeAnnotations(codes)

# %%
trainingUserDf = pd.concat([trainingUserDf,df_users],ignore_index=True)
trainingTweetDf = pd.concat([trainingTweetDf,df_tweets],ignore_index=True)

# %% [markdown]
# # 1. EXTRACT FEATURES
# Under *1.1. Political Tweet Detection* and *1.2. Bot Detection*, we firstly collect raw data for processing. We then combine some of them (total_interactions = num_favorites + num_retweets) or use them to extract features (whether the tweet has one of the political entities @meralaksener, @kilicdarogluk etc.).
#
# We expect you to collect more raw data from **tweet_metadata**, **user_profiles** and **user_tweets** files by creating a function as shown in below examples such as *check_if_retweet()* and using it while iterating over data as shown under *Merge Collected Features*.
#
# We also expect you to create new variables as much as you can from the data in order to make your predictions more accurate. For example, you may want to check:
#
# - The tweet sources that a user frequently uses
# - Whether the user is a verified account or not
#
# ...
#
# to assess whether **a user is a bot or not** and whether **a tweet is political or not**.

# %% [markdown]
# ### Read json files

# %%
PATH_TO_DOWNLOADED = DATA_PATH # 'D:/Users/suuser/Desktop/Sabancı/CS412/spring-2022/project/'

# %% [markdown]
# ## 1.1. Political Tweet Detection
# This part stands for the feature extraction of tweets. We start with collecting the raw data from *tweet_metadata*, then use some of them to extract features.

# %% [markdown]
# ### 1.1.1. Get Raw Data

# %% [markdown]
# #### 1.1.1.1. Check if Retweet

# %%
def check_if_retweet(tweet_metadata_line):
    is_retweet = 0
    retweeted_username = None

    try:
        tweet_metadata_line['retweeted_status']
        retweeted_username = tweet_metadata_line['retweeted_status']['user']['screen_name'].lower()
        is_retweet = 1

    except KeyError:
        pass

    return is_retweet, retweeted_username

# %% [markdown]
# #### 1.1.1.1. Check if Reply

# %%
def check_if_reply(tweet_metadata_line):
    is_reply = 0
    replied_username = None

    
    if(tweet_metadata_line['in_reply_to_screen_name'] != None ):
        replied_username = tweet_metadata_line['in_reply_to_screen_name'].lower()
        is_reply = 1



    return is_reply, replied_username

# %% [markdown]
# #### 1.1.1.1. Check if Verified

# %%
def check_if_verified(tweet_metadata_line):
     
    is_verified = tweet_metadata_line['user']['verified']  
    return is_verified

# %% [markdown]
# #### 1.1.1.2. Get Tweet Text

# %%
def get_tweet_text(tweet_metadata_line):
    text = tweet_metadata_line['text']
    
    return text

# %% [markdown]
# #### 1.1.1.3. Get Tweet ID

# %%
def get_tweet_id(tweet_metadata_line):
    id_str = tweet_metadata_line['id_str']
    
    return id_str

# %% [markdown]
# #### 1.1.1.4. Get Number of Mentions and Hashtags

# %%
def get_number_mentions_hashtags(tweet_metadata_line):
    num_mentions = len(tweet_metadata_line['entities']['user_mentions'])
    num_hashtags = len(tweet_metadata_line['entities']['hashtags'])

    return num_mentions, num_hashtags

# %% [markdown]
# #### 1.1.1.5. Get Number of Retweets and Favorites

# %%
def get_number_retweets_favorites(tweet_metadata_line):
    retweet_count = tweet_metadata_line['retweet_count']
    favorite_count = tweet_metadata_line['favorite_count']
    
    return retweet_count, favorite_count

# %% [markdown]
# #### 1.1.1.5. Get Number of Punctuations

# %%
def get_punc_num(text):
    punc = ['.', ',', '!', '?', ':', ';']
    count = 0
    for x in punc:
        if x in text:
            count += 1
    return count

# %% [markdown]
# #### 1.1.1.6. Get User Info

# %%
def get_user_info(tweet_metadata_line):
    id = tweet_metadata_line['user']['id_str']
    screen_name = tweet_metadata_line['user']['screen_name'].lower()
    description = tweet_metadata_line['user']['description']

    return id, screen_name, description

# %% [markdown]
# ### 1.1.2. Derive Manually Crafted Features

# %% [markdown]
# #### 1.1.2.1. Check for political entity in text

# %% [markdown]
#  ['meral_aksener', 'kilicdarogluk', 'vekilince', 'RTErdogan', 'MevlutCavusoglu', 'umitozdag','vedatbilgn','SavciSayan','fahrettinaltun','erdogan','devlet bahçeli','bahçeli','ülkü'
#                         'tcbestepe','fuatoktay','suleymansoylu','ikalin1','ekrem_imamoglu','mansuryavas06','pkk','recep','tayyip','erdoğan','cb','#ak','cumhuriyet'
#                         'hdp','terörist','chpkk','kadro','ek','tcbestepe','MevlutCavusoglu', 'ozdag', 'özdağ', 'TBMM','drfahrettinkoca', 'yenisafak', 'tayyip', 'cumhur', 'belediye', 'baskan', 'başkan', 'ulusal',
#                         'odatv', 'suleyman', 'haskologlu', 'mansur', 'dbdevletbahceli', 'Ahmet_Davutoglu', 'babacan', 'gazetesozcu', 'imamoglu', 'imamoğlu', 'parlament', 'meclis',
#                         'savaş', 'eğitim', 'egitim', 'dolar', 'lira', 'enflasyon', 'euro', 'döviz', 'altın', 'benzin', 'atama', 'altılı masa', 'abd', 'avrupa', 'almanya', 'nato',
#                         'sınır', 'göçmen', 'gocmen', 'sığınmacı', 'mülteci', 'mahkeme', 'kanun', 'ukrayna', 'rusya', 'komisyon', 'fetö', 'faiz', 'piyasa', 'banka', 'politik', 'toplantı', 'çiftçi',
#                         'saray', 'demokrasi', 'faşist', 'kemal', 'rejim', 'özgürlük', 'koalisyon', 'egemen', 'kurultay', 'danıştay', 'davutoğlu', 'birleşmiş milletler',
#                         'bahçeli', 'diplomasi', 'cem uzan', 'lgbt', 'seçim', '2023', 'ibb', 'cemaat', 'soylu', 'liberal', 'kapital', 'protesto', 'halk','seçim',
#                         'erken seçim','sandık','icraat','gençlik kolu','akp','chp','mhp', 'kayyum','anayasa','mahkeme','nebati','tcmb','merkez bankası','kılışdar','cumhurbaşkanı adayı','millet','zillet'
#                         'rte','atama','EYT','atanamıyor','kanun','soruşturma','sorusturma','altılı masa','bakanım','af','genel af', 'skandal','yolsuzluk','ihale','zafer','genelaf','muhalefet','muhalif','bakan'
#                        'meral_aksener', 'kilicdarogluk', 'vekilince', 'RTErdogan', 'MevlutCavusoglu', 'umitozdag','vedatbilgn','SavciSayan','fahrettinaltun',
#                         'tcbestepe','fuatoktay','suleymansoylu','ikalin1','ekrem_imamoglu','mansuryavas06','murat_kurum',
#                        'MevlutCavusoglu', 'drfahrettinkoca', 'NureddinNebati','akaraismailoglu','DIBAliErbas','ismailcatakli',
#                     'dbdevletbahceli', 'Ahmet_Davutoglu','deryayanikashb','suleymansoylu','06melihgokcek','mustafasentop','VahitKirisci',
#                      'fuatoktay','Akparti','emineerdoğan','iletisim','bybekirbozdag','omerrcelik','kasapoglu']

# %%
def check_political_ent(text):
    
    # the list below can be modified and some new names may be added (or removed)
    list_of_entities  = ['meral_aksener', 'kilicdarogluk', 'vekilince', 'RTErdogan', 'MevlutCavusoglu', 'umitozdag','vedatbilgn','SavciSayan','fahrettinaltun','erdogan','devlet bahçeli','bahçeli','ülkü'
                        'tcbestepe','fuatoktay','suleymansoylu','ikalin1','ekrem_imamoglu','mansuryavas06','pkk','recep','tayyip','erdoğan','cb','#ak','cumhuriyet'
                        'hdp','terörist','chpkk','kadro','ek','tcbestepe','MevlutCavusoglu', 'ozdag', 'özdağ', 'TBMM','drfahrettinkoca', 'yenisafak', 'tayyip', 'cumhur', 'belediye', 'baskan', 'başkan', 'ulusal',
                        'odatv', 'suleyman', 'haskologlu', 'mansur', 'dbdevletbahceli', 'Ahmet_Davutoglu', 'babacan', 'gazetesozcu', 'imamoglu', 'imamoğlu', 'parlament', 'meclis', 
                        'savaş', 'eğitim', 'egitim', 'dolar', 'lira', 'enflasyon', 'euro', 'döviz', 'altın', 'benzin', 'atama', 'altılı masa', 'abd', 'avrupa', 'almanya', 'nato',
                        'sınır', 'göçmen', 'gocmen', 'sığınmacı', 'mülteci', 'mahkeme', 'kanun', 'ukrayna', 'rusya', 'komisyon', 'fetö', 'faiz', 'piyasa', 'banka', 'politik', 'toplantı', 'çiftçi',
                        'saray', 'demokrasi', 'faşist', 'kemal', 'rejim', 'özgürlük', 'koalisyon', 'egemen', 'kurultay', 'danıştay', 'davutoğlu', 'birleşmiş milletler',
                        'bahçeli', 'diplomasi', 'cem uzan', 'lgbt', 'seçim', '2023', 'ibb', 'cemaat', 'soylu', 'liberal', 'kapital', 'protesto', 'halk','seçim', 
                        'erken seçim','sandık','icraat','gençlik kolu','akp','chp','mhp', 'kayyum','anayasa','mahkeme','nebati','tcmb','merkez bankası','kılışdar','cumhurbaşkanı adayı','millet','zillet'
                        'rte','atama','EYT','atanamıyor','kanun','soruşturma','sorusturma','altılı masa','bakanım','af','genel af', 'skandal','yolsuzluk','ihale','zafer','genelaf','muhalefet','muhalif','bakan'
                       'meral_aksener', 'kilicdarogluk', 'vekilince', 'RTErdogan', 'MevlutCavusoglu', 'umitozdag','vedatbilgn','SavciSayan','fahrettinaltun',
                        'tcbestepe','fuatoktay','suleymansoylu','ikalin1','ekrem_imamoglu','mansuryavas06','murat_kurum',
                       'MevlutCavusoglu', 'drfahrettinkoca', 'NureddinNebati','akaraismailoglu','DIBAliErbas','ismailcatakli',
                    'dbdevletbahceli', 'Ahmet_Davutoglu','deryayanikashb','suleymansoylu','06melihgokcek','mustafasentop','VahitKirisci',
                     'fuatoktay','Akparti','emineerdoğan','iletisim','bybekirbozdag','omerrcelik','kasapoglu']
    entities_in_text = [ent for ent in list_of_entities if ent.lower() in text.lower()]
    number_entities = len(entities_in_text)

    return number_entities

# %% [markdown]
# #### 1.1.2.2. Number of total interactions

# %%
def total_interactions(retweet_count, favorite_count):
    total_num_interactions = retweet_count + favorite_count
    
    return total_num_interactions

# %% [markdown]
# ### 1.1.2. Collect data using the functions above and transform into a Pandas DataFrame

# %%
dfPolitical = {'tweet_id':[],
              'is_retweet':[],
              'retweeted_username':[],
               'is_reply':[],
               'replied_username':[],
              'text':[],
              'num_mentions':[],
              'num_hashtags':[],
              'num_retweets':[],
              'num_favorites':[],
              'user_id':[],
              'user_screen_name':[],
              'user_description':[],
              'num_political_entities':[],
              'total_interactions':[],
              'punctuation': [],
              'tweet_length' : [],
              'is_verified': []}


with gzip.open(f"{PATH_TO_DOWNLOADED}tweet_metadata.jsons.gz", "rb") as f:
    for line in f:
        line = json.loads(line)
        
        # raw data:
        id_str = get_tweet_id(line)
        is_retweet, retweeted_username = check_if_retweet(line)
        is_reply, replied_username = check_if_reply(line)
        text = get_tweet_text(line)
        num_mentions, num_hashtags = get_number_mentions_hashtags(line)
        retweet_count, favorite_count = get_number_retweets_favorites(line)
        user_id_str, screen_name, user_description = get_user_info(line)
        punctuation = get_punc_num(text)
        is_verified = check_if_verified(line)
        tweet_length = len(text)
        # manually crafted data:
        num_political_entities = check_political_ent(text)
        total_num_interactions = total_interactions(retweet_count, favorite_count)

        dfPolitical['tweet_id'].append(id_str)
        dfPolitical['is_retweet'].append(is_retweet)
        dfPolitical['retweeted_username'].append(retweeted_username)
        dfPolitical['is_reply'].append(is_reply)
        dfPolitical['replied_username'].append(replied_username)
        dfPolitical['text'].append(text)
        dfPolitical['num_mentions'].append(num_mentions)
        dfPolitical['num_hashtags'].append(num_hashtags)
        dfPolitical['num_retweets'].append(retweet_count)
        dfPolitical['num_favorites'].append(favorite_count)
        dfPolitical['user_id'].append(user_id_str)
        dfPolitical['user_screen_name'].append(screen_name)
        dfPolitical['user_description'].append(user_description)
        dfPolitical['num_political_entities'].append(num_political_entities)
        dfPolitical['total_interactions'].append(total_num_interactions)
        dfPolitical['punctuation'].append(punctuation)
        dfPolitical['tweet_length'].append(tweet_length)
        dfPolitical['is_verified'].append(is_verified)

# %%
dfPolitical = pd.DataFrame(dfPolitical)
dfPolitical
# Out:
#                   tweet_id  is_retweet retweeted_username  is_reply  \
# 0      1588568792984346624           0               None         0
# 1      1588452263047069697           0               None         1
# 2      1569589330544398336           0               None         0
# 3      1570428119609139201           0               None         1
# 4      1551163840368414722           0               None         0
# ...                    ...         ...                ...       ...
# 33528  1568595408233832448           0               None         0
# 33529  1584027427696959488           0               None         1
# 33530  1585945783307730945           0               None         1
# 33531  1569748909521801221           1       muazzezeralp         0
# 33532  1585926877675282432           0               None         1
#
#       replied_username                                               text  \
# 0                 None  Sosyal Hizmetin temelini çocuk oluşturur,çocuğ...
# 1            mahirunal  @mahirunal Gavur İzmir ya onlar, hani Cumhuriy...
# 2                 None  #ŞehitAdayıUzmÇvşaKadro\nSiz İstesenizde Istem...
# 3         ajans_muhbir  @ajans_muhbir Siz kaypak olmayıp onay vermesey...
# 4                 None  Engelli öğretmenler olarak önümüzdeki engeller...
# ...                ...                                                ...
# 33528             None  Gerçek kimlik taşımayan hesaplara cevap vermem...
# 33529        umitozdag  @umitozdag Neden Suriyelilerle ilgili bu kadar...
# 33530    celebimehmeta  @celebimehmeta Niye Türkiye yüzyılıda.Türkiye ...
# 33531             None  RT @muazzezeralp: @Doan58213655 @denizkonur @N...
# 33532    bybekirbozdag  @bybekirbozdag Yasal işlemlerdn dolayı( banka,...
#
#        num_mentions  num_hashtags  num_retweets  num_favorites  \
# 0                 0             0            49             98
# 1                 1             0             0              0
# 2                 0             1             0              0
# 3                 1             0             0              0
# 4                 0             0             0              0
# ...             ...           ...           ...            ...
# 33528             0             0             9             81
# 33529             1             0             1              8
# 33530             1             0             0              1
# 33531             7             1             6              0
# 33532             1             0             0              0
#
#                    user_id user_screen_name  \
# 0       920963718103650304         maviruh_
# 1                595514060           mtfdan
# 2      1356375754561490947  ahsucilginuzman
# 3      1478775431008595968     hamitelkelle
# 4      1511976696337113088      sed58417690
# ...                    ...              ...
# 33528            576247173     ardanzenturk
# 33529            162308585         ozgul_61
# 33530            415025519        ladrekova
# 33531  1442125177727307781  yapikytgrivrlsn
# 33532  1180170443426320384  rodrige62822813
#
#                                         user_description  \
# 0         shu/\nburaya afilli bir söz yazdığımı varsayın
# 1
# 2                                        Vatan Sevdalisi
# 3                                                HighOne
# 4
# ...                                                  ...
# 33528  RT ONAYLADIĞIM ANLAMINA GELMEZ\nArtık fikirler...
# 33529      Bridge design engineer Yaay hesabı : dilfiruz
# 33530
# 33531
# 33532  Canı yanan sabretsin; can yakan da yanacağı gü...
#
#        num_political_entities  total_interactions  punctuation  tweet_length  \
# 0                           1                 147            3           140
# 1                           1                   0            2            97
# 2                           3                   0            3           140
# 3                           1                   0            2           140
# 4                           1                   0            3           140
# ...                       ...                 ...          ...           ...
# 33528                       1                  90            3           140
# 33529                       3                   9            2           140
# 33530                       1                   1            2            76
# 33531                       6                   6            1           140
# 33532                       4                   0            3           140
#
#        is_verified
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 33528        False
# 33529        False
# 33530        False
# 33531        False
# 33532        False
#
# [33533 rows x 18 columns]

# %% [markdown]
# ## 1.2. From Users

# %% [markdown]
# ### 1.2.1. Get user metadata from user_profiles.jsons.gz

# %% [markdown]
# #### 1.2.1.1. Get user info metadata

# %%
def get_user_info_metadata(user_metadata_line):
    
    user_id = user_metadata_line['id_str']
    user_name = user_metadata_line['name']
    user_screen_name = user_metadata_line['screen_name'].lower()
    user_location = user_metadata_line['location']
    user_description = user_metadata_line['description']
    user_followers_count = user_metadata_line['followers_count']
    user_friends_count = user_metadata_line['friends_count']
    user_created_at = user_metadata_line['created_at']
    user_protected = user_metadata_line['protected']
    user_verified = user_metadata_line['verified']
    user_geo_enabled = user_metadata_line['geo_enabled']
    user_tweet_count = user_metadata_line['statuses_count']
    user_fav_count = user_metadata_line['favourites_count']
    
    
    dictionary = {'user_id':user_id, 'user_name': user_name, 'user_screen_name':user_screen_name, 'user_location':user_location,
     'user_description':user_description, 'user_followers_count':user_followers_count, 'user_friends_count':user_friends_count, 
                  'user_created_at':user_created_at, 'user_protected':user_protected,
                  'user_verified': user_verified, 'user_geo_enabled':user_geo_enabled, 
                  'user_tweet_count':user_tweet_count, 'user_fav_count':user_fav_count}

    return dictionary

# %% [markdown]
# #### 1.2.1.2. Get followers/(followers+friends) ratio

# %%
def get_followers_all_ratio(user_followers_count, user_friends_count):
    
    if user_friends_count + user_followers_count == 0:
        followers_all_ratio = 0

    else:
        followers_all_ratio =  user_followers_count / (user_friends_count + user_followers_count)

    return followers_all_ratio

# %% [markdown]
# #### 1.2.1.3. Get description length

# %%
def get_desc_len(user_description):
    
    description_len = len(user_description)

    return description_len

# %% [markdown]
# #### 1.2.1.3. Get since

# %%
import time
from datetime import date
from datetime import datetime

# %% [markdown]
# #### 1.1.1.5. Get Number of Digits

# %%
def num_of_digits(username):
    count = 0

    for x in username:
        if x.isdigit():
            count+=1

    return count

# %%
def get_since(user_created_at):
    if user_created_at != None:
        creation_date = datetime.strptime(user_created_at ,'%a %b %d %H:%M:%S +0000 %Y')
        since = datetime.now() - creation_date
    else:
        since = 0
    return int(since.days)

# %%
dfBot = {'user_id':[],
         'user_name':[],
         'user_screen_name':[],
         'user_location':[],
         'user_description':[],
         'user_followers_count':[],
         'user_friends_count':[],
         'description_len':[],
         'followers_to_all_ratio':[],
        'user_created_at':[],
        'user_protected':[],
        'user_verified':[],
         'user_geo_enabled':[],
         'since':[],
         'user_tweet_count':[],
         'user_fav_count':[],
        'average_tweet': [],
        'average_fav': [],
        'count_digits': []}


with gzip.open(f"{PATH_TO_DOWNLOADED}user_profiles.jsons.gz", "rb") as f:
    for line in f:
        line = json.loads(line)

        dictionary = get_user_info_metadata(line)
        for k,v in dictionary.items():
            dfBot[k].append(v)

        
        # manually crafted data:
        description_len = get_desc_len(dictionary['user_description'])
        dfBot['description_len'].append(description_len)
        
        since = get_since(dictionary['user_created_at'])
        dfBot['since'].append(since)
        
        followers_all_ratio = get_followers_all_ratio(dictionary['user_followers_count'], 
                                                      dictionary['user_friends_count'])
        
        dfBot['average_tweet'].append(dictionary['user_tweet_count'] / since)
        dfBot['average_fav'].append(dictionary['user_fav_count'] / since)
        
        dfBot['count_digits'].append(num_of_digits(dictionary['user_screen_name']))

        dfBot['followers_to_all_ratio'].append(followers_all_ratio)

# %%
dfBot = pd.DataFrame(dfBot)
dfBot
# Out:
#                    user_id                                      user_name  \
# 0      1431241870848450577                            Nasreena Khan Wazir
# 1      1304340303080386560                                    fania :((((
# 2      1116042038577958914                                    Yusuf Aksoy
# 3               4859899931  Be (VIXX6) ama oppalarının düğününe gidemiyor
# 4               2225373636                                         SLMDMR
# ...                    ...                                            ...
# 29665  1320834618220781569                                        islammm
# 29666            111074128                                     Melda Onur
# 29667             36946875                                        ali ydm
# 29668           2389587396                                    Türkan Usta
# 29669           1575904134                                           ARAZ
#
#       user_screen_name            user_location  \
# 0      nasreenakhan006      Islamabad, Pakistan
# 1          scorpiehoez                   bogor
# 2      yusufak63712920
# 3       nedenburdaysam  Hufflepuff ortak salon
# 4          biologselim
# ...                ...                      ...
# 29665       islam_mrsj
# 29666        meldaonur
# 29667          ali_ydm        İstanbul, Türkiye
# 29668       turkanusta          Ankara, Türkiye
# 29669        ben121975
#
#                                         user_description  \
# 0                                                Student
# 1                                    have a holly jolly🎄
# 2      Bir şeyden pişmanlık duymak istemiyorsan,her ş...
# 3      SMStan\n/St☆rlight ///come on girls,this is ou...
# 4                               BİYOLOG🔬🦠\nNanoteknoloji
# ...                                                  ...
# 29665
# 29666  Şekersiz çay, etsiz sofra, SAVAŞSIZ dünya... 🐌...
# 29667                       hayat oyunsa bende jeton çok
# 29668  Ustaya sormuşlar; hayatta yaptığın en büyük is...
# 29669  Korkak gerçek le yüzleşmeyi redd eder,hırçınla...
#
#        user_followers_count  user_friends_count  description_len  \
# 0                        65                 185                7
# 1                      8235                3011               19
# 2                        95                 399               64
# 3                        40                  83               65
# 4                       100                  98               23
# ...                     ...                 ...              ...
# 29665                   229                 217                0
# 29666                212457                5428              100
# 29667                   116                 141               28
# 29668                  1669                3639              116
# 29669                  6026                5625              158
#
#        followers_to_all_ratio                 user_created_at  user_protected  \
# 0                    0.260000  Fri Aug 27 13:07:30 +0000 2021           False
# 1                    0.732260  Fri Sep 11 08:45:44 +0000 2020           False
# 2                    0.192308  Wed Apr 10 18:15:31 +0000 2019           False
# 3                    0.325203  Fri Jan 29 11:01:25 +0000 2016           False
# 4                    0.505051  Sun Dec 01 18:16:41 +0000 2013           False
# ...                       ...                             ...             ...
# 29665                0.513453  Mon Oct 26 21:08:22 +0000 2020           False
# 29666                0.975088  Wed Feb 03 18:39:01 +0000 2010           False
# 29667                0.451362  Fri May 01 13:56:23 +0000 2009           False
# 29668                0.314431  Fri Mar 14 18:05:09 +0000 2014           False
# 29669                0.517209  Sun Jul 07 19:57:01 +0000 2013           False
#
#        user_verified  user_geo_enabled  since  user_tweet_count  \
# 0              False              True    515              2551
# 1              False              True    865             42771
# 2              False             False   1384             14300
# 3              False             False   2552             21303
# 4              False             False   3340              1629
# ...              ...               ...    ...               ...
# 29665          False             False    819              2396
# 29666          False              True   4737             75178
# 29667          False             False   5015              6482
# 29668          False              True   3237            121113
# 29669          False              True   3487              7120
#
#        user_fav_count  average_tweet  average_fav  count_digits
# 0               17676       4.953398    34.322330             3
# 1               15474      49.446243    17.889017             0
# 2               18220      10.332370    13.164740             8
# 3               26999       8.347571    10.579545             0
# 4                2179       0.487725     0.652395             0
# ...               ...            ...          ...           ...
# 29665           10820       2.925519    13.211233             0
# 29666           36671      15.870382     7.741398             0
# 29667            7389       1.292522     1.473380             0
# 29668          140095      37.415199    43.279271             0
# 29669           39605       2.041870    11.357901             6
#
# [29670 rows x 19 columns]

# %% [markdown]
# ### 1.2.2. Get Tweet Info of Users in user_profiles.jsons.gz

# %% [markdown]
# #### 1.2.2.1. Check ratio of retweets to all tweets

# %%
def get_retweet_tweet_ratio(line):
    number_retweets = 0
    number_original_tweets = 0

    for tweet in line['tweets']:
        try:
            tweet['retweeted_status']
            number_retweets += 1
                
        except:
            number_original_tweets += 1
            
    total_tweets = number_retweets + number_original_tweets
    
    if total_tweets == 0:
        retweet_total_ratio = None
    else:
        retweet_total_ratio = number_retweets/(total_tweets)
    
    return retweet_total_ratio

# %% [markdown]
# #### 1.2.2.2. Check median number of favorites

# %%
def get_median_number_favorites(line):
    num_median_favorites = np.median([tweet['favorite_count'] for tweet in line['tweets']])

    return num_median_favorites

# %% [markdown]
# ### 1.2.3. Collect data using the functions above and transform into a Pandas DataFrame

# %%
dfBotTweets = {'user_id':[],
               'retweet_total_ratio':[],
               'num_median_favorites':[],
               'num_of_tweets':[]
              }

i = 0

with gzip.open(f"{PATH_TO_DOWNLOADED}user_tweets.jsons.gz", "rb") as f:
    for line in f:

        line = json.loads(line)

        user_id = line['user_id']
        dfBotTweets['user_id'].append(user_id)
        
        retweet_total_ratio = get_retweet_tweet_ratio(line)
        dfBotTweets['retweet_total_ratio'].append(retweet_total_ratio)
        
        num_median_favorites = get_median_number_favorites(line)
        dfBotTweets['num_median_favorites'].append(num_median_favorites)
        
        dfBotTweets['num_of_tweets'].append(len(line['tweets']))

        i += 1
        if i % 1000 == 0:
            print(i)
# Out:
# C:\Users\Gamegaraj\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Gamegaraj\AppData\Roaming\Python\Python39\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000

# %%
dfBotTweets = pd.DataFrame(dfBotTweets)
dfBotTweets
# Out:
#                    user_id  retweet_total_ratio  num_median_favorites  \
# 0                594642154             0.115000                   2.0
# 1                525600289             0.005025                   1.0
# 2       931895965501534209             0.900000                   0.0
# 3      1591543462746329088             0.185000                   0.0
# 4       734801354749796352             1.000000                   0.0
# ...                    ...                  ...                   ...
# 28310  1591370361488252928             0.800000                   0.0
# 28311  1475272459616235525             0.825000                   0.0
# 28312  1096753792731750401             0.051020                   1.0
# 28313  1269527617687953409             0.095000                   2.0
# 28314  1483177252271570944             0.630000                   0.0
#
#        num_of_tweets
# 0                200
# 1                199
# 2                200
# 3                200
# 4                200
# ...              ...
# 28310            200
# 28311            200
# 28312            196
# 28313            200
# 28314            200
#
# [28315 rows x 4 columns]

# %%
dfBotTweets.describe()
# Out:
#        retweet_total_ratio  num_median_favorites  num_of_tweets
# count         28232.000000          28232.000000   28315.000000
# mean              0.359703              9.763690     189.178739
# std               0.351173            215.705174      36.092954
# min               0.000000              0.000000       0.000000
# 25%               0.035000              0.000000     198.000000
# 50%               0.226131              0.000000     200.000000
# 75%               0.675127              1.000000     200.000000
# max               1.000000          25659.000000     200.000000

# %% [markdown]
# ### 1.2.3. Merge dfBot and dfBotTweets

# %%
dfBotTweets[[ 'num_median_favorites','retweet_total_ratio']] = dfBotTweets[[ 'num_median_favorites','retweet_total_ratio']].fillna(0)

# %%
dfBotAll = dfBot.merge(dfBotTweets, how='left')

# %%
dfBotAll.isna().sum()
# Out:
# user_id                      0
# user_name                    0
# user_screen_name             0
# user_location                0
# user_description             0
# user_followers_count         0
# user_friends_count           0
# description_len              0
# followers_to_all_ratio       0
# user_created_at              0
# user_protected               0
# user_verified                0
# user_geo_enabled             0
# since                        0
# user_tweet_count             0
# user_fav_count               0
# average_tweet                0
# average_fav                  0
# count_digits                 0
# retweet_total_ratio       1355
# num_median_favorites      1355
# num_of_tweets             1355
# dtype: int64

# %%
dfBotAll[['retweet_total_ratio', 'num_median_favorites','num_of_tweets']] = dfBotAll[['retweet_total_ratio', 'num_median_favorites','num_of_tweets']].fillna(0)

dfBotAll[['user_protected', 'user_verified','user_geo_enabled']] = dfBotAll[['user_protected', 'user_verified','user_geo_enabled']].astype(int)

# %% [markdown]
# # 2. TRAIN MODEL

# %% [markdown]
# ## 2.1. Political Tweet Prediction

# %% [markdown]
# ### 2.1.1. Merge dfPolitical data with labels

# %%
dfPoliticalAll_train = dfPolitical.merge(trainingTweetDf,on='tweet_id')

# %%
dfPoliticalAll_train.select_dtypes('bool')
dfPoliticalAll_train['is_verified'] = dfPoliticalAll_train['is_verified'].astype(int)

# %% [markdown]
# ### 2.1.2. Separate X and y values
# We only use 3 features here to create a baseline model. However, it is not enough to get good results.

# %%
dfPoliticalAll_train.select_dtypes(exclude=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3994 entries, 0 to 3993
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   is_retweet              3994 non-null   int64
#  1   is_reply                3994 non-null   int64
#  2   num_mentions            3994 non-null   int64
#  3   num_hashtags            3994 non-null   int64
#  4   num_retweets            3994 non-null   int64
#  5   num_favorites           3994 non-null   int64
#  6   num_political_entities  3994 non-null   int64
#  7   total_interactions      3994 non-null   int64
#  8   punctuation             3994 non-null   int64
#  9   tweet_length            3994 non-null   int64
#  10  is_verified             3994 non-null   int32
# dtypes: int32(1), int64(10)
# memory usage: 358.8 KB

# %%
#X = dfPoliticalAll_train[['num_political_entities','total_interactions','num_hashtags']]
#y = dfPoliticalAll_train['isPolitical'].apply(lambda x: 1 if x=='Yes' else 0)

X = dfPoliticalAll_train.select_dtypes(exclude=['object'])
#X = dfPoliticalAll_train[['is_reply', 'num_mentions', 'num_hashtags', 'num_retweets',
                        #  'num_favorites', 'num_political_entities', 'punctuation', 'is_verified']]
y = dfPoliticalAll_train['isPolitical'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3994 entries, 0 to 3993
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   is_retweet              3994 non-null   int64
#  1   is_reply                3994 non-null   int64
#  2   num_mentions            3994 non-null   int64
#  3   num_hashtags            3994 non-null   int64
#  4   num_retweets            3994 non-null   int64
#  5   num_favorites           3994 non-null   int64
#  6   num_political_entities  3994 non-null   int64
#  7   total_interactions      3994 non-null   int64
#  8   punctuation             3994 non-null   int64
#  9   tweet_length            3994 non-null   int64
#  10  is_verified             3994 non-null   int32
# dtypes: int32(1), int64(10)
# memory usage: 358.8 KB

# %%
from sklearn.preprocessing import StandardScaler
num_cols = X.select_dtypes(include=np.number).columns.tolist()

ss = StandardScaler()
X = pd.DataFrame(ss.fit_transform(X[num_cols]), columns=num_cols)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# Initialize the model
lr = LogisticRegression()

# Perform RFE and select the top 15 features
rfe = RFE(lr, n_features_to_select=8)
X_new = rfe.fit_transform(X, y)

# Print the features that have been selected
print("Selected features:", [X.columns[i] for i in range(len(X.columns)) if rfe.support_[i]])
# Out:
# Selected features: ['is_reply', 'num_mentions', 'num_retweets', 'num_favorites', 'num_political_entities', 'total_interactions', 'punctuation', 'tweet_length']

# %%
X = dfPoliticalAll_train.select_dtypes(exclude=['object'])
#X = dfPoliticalAll_train[ ['is_reply', 'num_mentions', 'num_retweets', 'num_favorites', 'num_political_entities', 'total_interactions', 'punctuation', 'tweet_length']]
y = dfPoliticalAll_train['isPolitical'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3994 entries, 0 to 3993
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   is_retweet              3994 non-null   int64
#  1   is_reply                3994 non-null   int64
#  2   num_mentions            3994 non-null   int64
#  3   num_hashtags            3994 non-null   int64
#  4   num_retweets            3994 non-null   int64
#  5   num_favorites           3994 non-null   int64
#  6   num_political_entities  3994 non-null   int64
#  7   total_interactions      3994 non-null   int64
#  8   punctuation             3994 non-null   int64
#  9   tweet_length            3994 non-null   int64
#  10  is_verified             3994 non-null   int32
# dtypes: int32(1), int64(10)
# memory usage: 358.8 KB

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# Initialize SMOTE
sm = SMOTE(random_state=42)

# Perform oversampling
X_resampled, y_resampled = sm.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_valid, y_train, y_valid = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import VotingClassifier

# Initialize the models
ada = AdaBoostClassifier(n_estimators=100, learning_rate=0.1)
xgb = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.1)
lgb = LGBMClassifier(n_estimators=100, max_depth=5, learning_rate=0.1)
rf = RandomForestClassifier(n_estimators=100, max_depth=5)

# Create the ensemble model
ensemble = VotingClassifier(estimators=[('ada', ada), ('xgb', xgb), ('lgb', lgb), ('rf', rf)], voting='hard')

# Fit the ensemble model on the training data
ensemble.fit(X_train, y_train)

# Make predictions on the test data
y_pred = ensemble.predict(X_valid)

# Print the accuracy
print("Accuracy:", ensemble.score(X_valid, y_valid))
# Out:
# Accuracy: 0.8127009646302251

# %%
X_resampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6220 entries, 0 to 6219
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_followers_count    6220 non-null   float64
#  1   user_friends_count      6220 non-null   float64
#  2   description_len         6220 non-null   float64
#  3   followers_to_all_ratio  6220 non-null   float64
#  4   user_protected          6220 non-null   float64
#  5   user_verified           6220 non-null   float64
#  6   user_geo_enabled        6220 non-null   float64
#  7   since                   6220 non-null   float64
#  8   user_tweet_count        6220 non-null   float64
#  9   user_fav_count          6220 non-null   float64
#  10  average_tweet           6220 non-null   float64
#  11  average_fav             6220 non-null   float64
#  12  count_digits            6220 non-null   float64
#  13  retweet_total_ratio     6220 non-null   float64
#  14  num_median_favorites    6220 non-null   float64
#  15  num_of_tweets           6220 non-null   float64
# dtypes: float64(16)
# memory usage: 777.6 KB

# %% [markdown]
# ### 2.1.3. Train - validation split

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### 2.1.4. Train the model
#
# Here, you may use different models such as neural networks, XGBoost, AdaBoost, RandomForest, Linear Regression, Logistic Regression etc. to see which model does the best. Also, you can use grid_search_cv() or a basic for loop to optimize the hyperparameters of your model.

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split



# Feature selection
# Select the top 10 best features
selector = SelectKBest(k=9)
X_new = selector.fit_transform(X, y)

# Split the data into training and test sets
X_train, X_valid, y_train, y_valid = train_test_split(X_new, y, test_size=0.2)

# Neural network
clf = MLPClassifier(hidden_layer_sizes=(50,), max_iter=10000, random_state=0)
clf.fit(X_train, y_train)

# Evaluation
accuracy = clf.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7468030690537084

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import VotingClassifier

# %%
# Import Library
from sklearn.linear_model import LogisticRegression  
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# %%
LR= LogisticRegression(max_iter=300).fit(X_train, y_train)
# predicting
preds = LR.predict(X_valid)

# classification report
target_names = ['bot', 'not bot']
print('Classification_Report:')
print(classification_report(y_valid, preds, digits=4, target_names = target_names))
# Out:
# Classification_Report:
#               precision    recall  f1-score   support
#
#          bot     0.8363    0.9728    0.8994       625
#      not bot     0.6909    0.2420    0.3585       157
#
#     accuracy                         0.8261       782
#    macro avg     0.7636    0.6074    0.6289       782
# weighted avg     0.8071    0.8261    0.7908       782

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.17391304347826086
#  Accuracy Score: 0.8260869565217391
#  Confusion Matrix:
#  [[608  17]
#  [119  38]]

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc_p=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)


lgbc_p.fit(X_train, y_train)
preds = lgbc_p.predict(X_valid)

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.17519181585677748
#  Accuracy Score: 0.8248081841432225
#  Confusion Matrix:
#  [[600  25]
#  [112  45]]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

# %%
adb_ros = AdaBoostClassifier(n_estimators = 100)
adb_ros.fit(X_train, y_train)

#predicting
preds = adb_ros.predict(X_valid)

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.17774936061381075
#  Accuracy Score: 0.8222506393861893
#  Confusion Matrix:
#  [[594  31]
#  [108  49]]

# %% [markdown]
# from sklearn.model_selection import GridSearchCV

# %% [markdown]
# rfc=RandomForestClassifier(random_state=42)
# param_grid = {
#     'n_estimators': [200, 500],
#     'max_features': ['auto', 'sqrt', 'log2'],
#     'max_depth' : [4,5,6,7,8],
#     'criterion' :['gini', 'entropy']
# }
# CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
# CV_rfc.fit(X_train, y_train)

# %% [markdown]
# CV_rfc.best_params_

# %%
rf_ros_p = RandomForestClassifier(max_depth=20, n_estimators=3000)
rf_ros_p.fit(X_train, y_train)

#predicting
preds = rf_ros_p.predict(X_valid)

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.1636828644501279
#  Accuracy Score: 0.8363171355498721
#  Confusion Matrix:
#  [[604  21]
#  [107  50]]

# %%
rf_ros_b = RandomForestClassifier(criterion= 'gini',
 max_depth= 20,
 max_features ='auto',
 n_estimators = 800)
rf_ros_b.fit(X_train, y_train)

#predicting
preds = rf_ros_b.predict(X_valid)
# Out:
# C:\Users\Gamegaraj\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.16751918158567775
#  Accuracy Score: 0.8324808184143222
#  Confusion Matrix:
#  [[604  21]
#  [110  47]]

# %% [markdown]
# from sklearn import preprocessing
# from sklearn.cross_validation import train_test_split
#
#
# from sklearn.grid_search import GridSearchCV

# %% [markdown]
# estimator = XGBClassifier(
#     objective= 'binary:logistic',
#     nthread=4,
#     seed=42
# )

# %% [markdown]
# xgb_model = XGBClassifier()
# parameters = {
#     'max_depth': range (2, 10, 1),
#     'n_estimators': range(60, 220, 40),
#     'learning_rate': [0.1, 0.01, 0.05]
# }

# %% [markdown]
# grid_search = GridSearchCV(
#     estimator=estimator,
#     param_grid=parameters,
#     scoring = 'roc_auc',
#     n_jobs = 10,
#     cv = 10,
#     verbose=True
# )
#
# grid_search.fit(X_train, y_train)

# %% [markdown]
# grid_search.best_params_

# %%
from xgboost import XGBClassifier
xgb_ros_p = XGBClassifier(learning_rate= 0.1, max_depth =  4, n_estimators =  60)
xgb_ros_p.fit(X_train, y_train)

#predicting
preds = xgb_ros_p.predict(X_valid)

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.17135549872122763
#  Accuracy Score: 0.8286445012787724
#  Confusion Matrix:
#  [[601  24]
#  [110  47]]

# %%
import keras.utils
from tensorflow.keras import utils as np_utils
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import SGD, Adam
import tensorflow as tf
model_1 = tf.keras.Sequential()
model_1.add(tf.keras.layers.Dense(100, activation='relu', name='hidden_layer_1'))
model_1.add(tf.keras.layers.Dense(50, activation='relu', name='hidden_layer_2'))
model_1.add(tf.keras.layers.Dense(25, activation='relu', name='hidden_layer_3'))
model_1.add(tf.keras.layers.Dense(1, name='output_layer'))

# compile your model with an optimizer
model_1.compile(loss='mean_squared_error', optimizer = Adam(learning_rate=0.001), metrics=['mse','accuracy'])


model_1.fit(X_train, y_train, epochs=50, batch_size=64, shuffle=True, verbose=1)
# Out:
# Epoch 1/50
# 49/49 [==============================] - 0s 1ms/step - loss: 0.1479 - mse: 0.1479 - accuracy: 0.8049
# Epoch 2/50
# 49/49 [==============================] - 0s 708us/step - loss: 0.1302 - mse: 0.1302 - accuracy: 0.8139
# Epoch 3/50
# 49/49 [==============================] - 0s 926us/step - loss: 0.1263 - mse: 0.1263 - accuracy: 0.8235
# Epoch 4/50
# 49/49 [==============================] - 0s 867us/step - loss: 0.1265 - mse: 0.1265 - accuracy: 0.8251
# Epoch 5/50
# 49/49 [==============================] - 0s 971us/step - loss: 0.1233 - mse: 0.1233 - accuracy: 0.8286
# Epoch 6/50
# 49/49 [==============================] - 0s 770us/step - loss: 0.1211 - mse: 0.1211 - accuracy: 0.8324
# Epoch 7/50
# 49/49 [==============================] - 0s 992us/step - loss: 0.1208 - mse: 0.1208 - accuracy: 0.8359
# Epoch 8/50
# 49/49 [==============================] - 0s 941us/step - loss: 0.1200 - mse: 0.1200 - accuracy: 0.8343
# Epoch 9/50
# 49/49 [==============================] - 0s 1ms/step - loss: 0.1199 - mse: 0.1199 - accuracy: 0.8327
# Epoch 10/50
# 49/49 [==============================] - 0s 880us/step - loss: 0.1164 - mse: 0.1164 - accuracy: 0.8382
# Epoch 11/50
# 49/49 [==============================] - 0s 1ms/step - loss: 0.1152 - mse: 0.1152 - accuracy: 0.8414
# Epoch 12/50
# 49/49 [==============================] - 0s 990us/step - loss: 0.1166 - mse: 0.1166 - accuracy: 0.8382
# Epoch 13/50
# 49/49 [==============================] - 0s 1ms/step - loss: 0
# 49/49 [==============================] - 0s 959us/step - loss: 0.0906 - mse: 0.0906 - accuracy: 0.8740
# Epoch 50/50
# 49/49 [==============================] - 0s 948us/step - loss: 0.0907 - mse: 0.0907 - accuracy: 0.8746

# %% [markdown]
# preds = model_1.predict(X_valid)

# %% [markdown]
# preds

# %% [markdown]
# acc_score = accuracy_score(y_valid, preds)
# confusion = confusion_matrix(y_valid, preds)
# mse = mean_squared_error(y_valid, preds)
#
# print("MSE:", mse, "\n",
#       "Accuracy Score:", acc_score, "\n",
#       "Confusion Matrix:", "\n", confusion)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# create an instance
dtc_political = DecisionTreeClassifier()
param_grid = {'criterion':['gini','entropy'], 'max_depth':[3,5,7,9,11]}
grid = GridSearchCV(dtc_political,
                    param_grid, 
                    cv=28,
                    scoring='precision',
                    return_train_score=False, 
                    verbose=1, 
                    refit=True)


# fit your model
grid_search = grid.fit(X_train, y_train)

# make predictions
preds = grid_search.predict(X_valid)

# evaluate on validation set
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# Fitting 28 folds for each of 10 candidates, totalling 280 fits
# C:\Users\Gamegaraj\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Gamegaraj\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# MSE: 0.20076726342711
#  Accuracy Score: 0.7992327365728901
#  Confusion Matrix:
#  [[592  33]
#  [124  33]]

# %% [markdown]
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error
#
# # create an instance
# dtc_political = DecisionTreeClassifier()
#
# # fit your model
# dtc_political.fit(X_train, y_train)
#
# # make predictions
# preds = dtc_political.predict(X_valid)
#
# # evaluate on validation set
# acc_score = accuracy_score(y_valid, preds)
# confusion = confusion_matrix(y_valid, preds)
# mse = mean_squared_error(y_valid, preds)
#
# print("MSE:", mse, "\n",
#       "Accuracy Score:", acc_score, "\n",
#       "Confusion Matrix:", "\n", confusion)

# %% [markdown]
# ## 2.2. Bot Detection

# %% [markdown]
# ### 2.2.1. Merge dfBotAll data with labels

# %%
dfBotAll.user_screen_name = dfBotAll.user_screen_name.str.lower()

# %%
dfBotAll_train = dfBotAll.merge(trainingUserDf,
                               left_on='user_screen_name',
                               right_on='screen_name')

dfBotAll_train
# Out:
#                   user_id                 user_name user_screen_name  \
# 0     1431241870848450577       Nasreena Khan Wazir  nasreenakhan006
# 1     1431241870848450577       Nasreena Khan Wazir  nasreenakhan006
# 2     1304340303080386560               fania :((((      scorpiehoez
# 3     1304340303080386560               fania :((((      scorpiehoez
# 4     1304340303080386560               fania :((((      scorpiehoez
# ...                   ...                       ...              ...
# 3904  1286770207134973954            Hamide Arabacı         anka6054
# 3905  1598032338323214338      atamabekleyenbahceci  atamabekleyenzz
# 3906   760235343966863360                Emrah İNCİ       memrahinci
# 3907  1553973684100124672                 Murat Kkk       muratkkk18
# 3908  1392390985645281283  Münferit Fenerbahçeliler  mnferitfenerba1
#
#             user_location                                   user_description  \
# 0     Islamabad, Pakistan                                            Student
# 1     Islamabad, Pakistan                                            Student
# 2                  bogor                                 have a holly jolly🎄
# 3                  bogor                                 have a holly jolly🎄
# 4                  bogor                                 have a holly jolly🎄
# ...                   ...                                                ...
# 3904
# 3905
# 3906   Istanbul - Bayburt  Researcher | Middle East | Political Science |...
# 3907                                              Normal sıradan bir insanım
# 3908                       Fenerbahçe S.K. Kongre Üyesi Kırmızı çizgileri...
#
#       user_followers_count  user_friends_count  description_len  \
# 0                       65                 185                7
# 1                       65                 185                7
# 2                     8235                3011               19
# 3                     8235                3011               19
# 4                     8235                3011               19
# ...                    ...                 ...              ...
# 3904                   151                  61                0
# 3905                   173                 367                0
# 3906                  5863                5905               71
# 3907                     1                  10               26
# 3908                   281                 270              156
#
#       followers_to_all_ratio                 user_created_at  user_protected  \
# 0                   0.260000  Fri Aug 27 13:07:30 +0000 2021               0
# 1                   0.260000  Fri Aug 27 13:07:30 +0000 2021               0
# 2                   0.732260  Fri Sep 11 08:45:44 +0000 2020               0
# 3                   0.732260  Fri Sep 11 08:45:44 +0000 2020               0
# 4                   0.732260  Fri Sep 11 08:45:44 +0000 2020               0
# ...                      ...                             ...             ...
# 3904                0.712264  Fri Jul 24 21:08:34 +0000 2020               0
# 3905                0.320370  Wed Nov 30 19:13:03 +0000 2022               0
# 3906                0.498215  Mon Aug 01 22:06:45 +0000 2016               0
# 3907                0.090909  Mon Aug 01 05:19:56 +0000 2022               0
# 3908                0.509982  Wed May 12 08:08:04 +0000 2021               0
#
#       user_verified  user_geo_enabled  since  user_tweet_count  \
# 0                 0                 1    515              2551
# 1                 0                 1    515              2551
# 2                 0                 1    865             42771
# 3                 0                 1    865             42771
# 4                 0                 1    865             42771
# ...             ...               ...    ...               ...
# 3904              0                 0    913              5288
# 3905              0                 0     54               311
# 3906              0                 1   2366              1029
# 3907              0                 0    176                18
# 3908              0                 1    622              7165
#
#       user_fav_count  average_tweet  average_fav  count_digits  \
# 0              17676       4.953398    34.322330             3
# 1              17676       4.953398    34.322330             3
# 2              15474      49.446243    17.889017             0
# 3              15474      49.446243    17.889017             0
# 4              15474      49.446243    17.889017             0
# ...              ...            ...          ...           ...
# 3904            5347       5.791895     5.856517             4
# 3905             196       5.759259     3.629630             0
# 3906             725       0.434911     0.306424             0
# 3907              38       0.102273     0.215909             2
# 3908            4106      11.519293     6.601286             1
#
#       retweet_total_ratio  num_median_favorites  num_of_tweets  \
# 0                0.395939                   0.0          197.0
# 1                0.395939                   0.0          197.0
# 2                0.125000                   0.0          200.0
# 3                0.125000                   0.0          200.0
# 4                0.125000                   0.0          200.0
# ...                   ...                   ...            ...
# 3904             0.000000                   1.0          200.0
# 3905             0.580000                   0.0          200.0
# 3906             0.040000                  36.0          200.0
# 3907             0.769231                   0.0           13.0
# 3908             0.045000                   1.0          200.0
#
#           screen_name isBot
# 0     nasreenakhan006    No
# 1     nasreenakhan006    No
# 2         scorpiehoez    No
# 3         scorpiehoez    No
# 4         scorpiehoez    No
# ...               ...   ...
# 3904         anka6054    No
# 3905  atamabekleyenzz    No
# 3906       memrahinci    No
# 3907       muratkkk18    No
# 3908  mnferitfenerba1    No
#
# [3909 rows x 24 columns]

# %% [markdown]
# ### 2.2.2. Separate X and y values
# We use only 4 features here to create a baseline model. However, it is not enough to get good results.

# %%
X = dfBotAll_train.select_dtypes(exclude=['object'])
y = dfBotAll_train.isBot.apply(lambda x: 1 if x=='Yes' else 0)

# %%
dfBotAll_train.select_dtypes(exclude=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3909 entries, 0 to 3908
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_followers_count    3909 non-null   int64
#  1   user_friends_count      3909 non-null   int64
#  2   description_len         3909 non-null   int64
#  3   followers_to_all_ratio  3909 non-null   float64
#  4   user_protected          3909 non-null   int32
#  5   user_verified           3909 non-null   int32
#  6   user_geo_enabled        3909 non-null   int32
#  7   since                   3909 non-null   int64
#  8   user_tweet_count        3909 non-null   int64
#  9   user_fav_count          3909 non-null   int64
#  10  average_tweet           3909 non-null   float64
#  11  average_fav             3909 non-null   float64
#  12  count_digits            3909 non-null   int64
#  13  retweet_total_ratio     3909 non-null   float64
#  14  num_median_favorites    3909 non-null   float64
#  15  num_of_tweets           3909 non-null   float64
# dtypes: float64(6), int32(3), int64(7)
# memory usage: 473.4 KB

# %%
from sklearn.preprocessing import StandardScaler
num_cols = X.select_dtypes(include=np.number).columns.tolist()

ss = StandardScaler()
X = pd.DataFrame(ss.fit_transform(X[num_cols]), columns=num_cols)

# %% [markdown]
# ### 2.2.3. Train-test split

# %%
X_train.shape
# Out:
# (3127, 9)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# Load the account features
account_features = X # list of account features (e.g., number of followers, account age, etc.)
labels = y # list of labels (bot or not)

#Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(account_features, labels, test_size=0.2)

# Define the model
model = Sequential()
model.add(LSTM(units=32, input_shape=(account_features.shape[1],1)))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Reshape the data for LSTM


# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=30)

# Evaluate the model on the test set
score, acc = model.evaluate(X_test, y_test, batch_size=32)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Epoch 1/30
# 98/98 [==============================] - 2s 4ms/step - loss: 0.5293 - accuracy: 0.7867
# Epoch 2/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4447 - accuracy: 0.8052
# Epoch 3/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4395 - accuracy: 0.8043
# Epoch 4/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4367 - accuracy: 0.8046
# Epoch 5/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4370 - accuracy: 0.8056
# Epoch 6/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4350 - accuracy: 0.8078
# Epoch 7/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4331 - accuracy: 0.8088
# Epoch 8/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4343 - accuracy: 0.8065
# Epoch 9/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4337 - accuracy: 0.8075
# Epoch 10/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4330 - accuracy: 0.8100
# Epoch 11/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4323 - accuracy: 0.8088
# Epoch 12/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4308 - accuracy: 0.8100
# Epoch 13/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4306 - accuracy: 0.8100
# Epoch 14/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4300 - accuracy: 0.8094
# Epoch 15/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4300 - accuracy: 0.8081
# Epoch 16/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4285 - accuracy: 0.8088
# Epoch 17/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.8097
# Epoch 18/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4277 - accuracy: 0.8097
# Epoch 19/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4284 - accuracy: 0.8110
# Epoch 20/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4269 - accuracy: 0.8107
# Epoch 21/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4276 - accuracy: 0.8088
# Epoch 22/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4263 - accuracy: 0.8088
# Epoch 23/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.8100
# Epoch 24/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4258 - accuracy: 0.8094
# Epoch 25/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4231 - accuracy: 0.8110
# Epoch 26/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.8113
# Epoch 27/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4199 - accuracy: 0.8139
# Epoch 28/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4188 - accuracy: 0.8136
# Epoch 29/30
# 98/98 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.8139
# Epoch 30/30
# 98/98 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.8139
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4461 - accuracy: 0.7992
# Test score: 0.4460867643356323
# Test accuracy: 0.7992327213287354

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
LR= LogisticRegression(max_iter=300).fit(X_train, y_train)
# predicting
preds = LR.predict(X_valid)

# classification report
target_names = ['bot', 'not bot']
print('Classification_Report:')
print(classification_report(y_valid, preds, digits=4, target_names = target_names))
# Out:
# Classification_Report:
#               precision    recall  f1-score   support
#
#          bot     0.8254    0.9760    0.8944       625
#      not bot     0.6512    0.1783    0.2800       157
#
#     accuracy                         0.8159       782
#    macro avg     0.7383    0.5772    0.5872       782
# weighted avg     0.7905    0.8159    0.7711       782

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.18414322250639387
#  Accuracy Score: 0.8158567774936062
#  Confusion Matrix:
#  [[610  15]
#  [129  28]]

# %%
adb_ros = AdaBoostClassifier(n_estimators = 250)
adb_ros.fit(X_train, y_train)

#predicting
preds = adb_ros.predict(X_valid)

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.17647058823529413
#  Accuracy Score: 0.8235294117647058
#  Confusion Matrix:
#  [[602  23]
#  [115  42]]

# %%
rf_ros_b = RandomForestClassifier(criterion= 'entropy',
 max_depth= 14,
 max_features ='auto',
 n_estimators = 800)
rf_ros_b.fit(X_train, y_train)

#predicting
preds = rf_ros_b.predict(X_valid)
# Out:
# C:\Users\Gamegaraj\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.1636828644501279
#  Accuracy Score: 0.8363171355498721
#  Confusion Matrix:
#  [[601  24]
#  [104  53]]

# %%
from xgboost import XGBClassifier
xgb_ros_b = XGBClassifier(learning_rate= 0.1, max_depth =  17, n_estimators =  95)
xgb_ros_b.fit(X_train, y_train)

#predicting
preds = xgb_ros_b.predict(X_valid)

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.16879795396419436
#  Accuracy Score: 0.8312020460358056
#  Confusion Matrix:
#  [[593  32]
#  [100  57]]

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc_b=LGBMClassifier(n_estimators=500, learning_rate=0.06, num_leaves=64, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)


lgbc_b.fit(X_train, y_train)
preds = lgbc_b.predict(X_valid)

# %%
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.17263427109974425
#  Accuracy Score: 0.8273657289002557
#  Confusion Matrix:
#  [[602  23]
#  [112  45]]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# create an instance
dtc_political = DecisionTreeClassifier()
param_grid = {'criterion':['gini','entropy'], 'max_depth':[3,5,7,9,11]}
grid = GridSearchCV(dtc_political,
                    param_grid, 
                    cv=28,
                    scoring='precision',
                    return_train_score=False, 
                    verbose=1, 
                    refit=True)


# fit your model
grid_search = grid.fit(X_train, y_train)

# make predictions
preds = grid_search.predict(X_valid)

# evaluate on validation set
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# Fitting 28 folds for each of 10 candidates, totalling 280 fits
# MSE: 0.18797953964194372
#  Accuracy Score: 0.8120204603580563
#  Confusion Matrix:
#  [[611  14]
#  [133  24]]

# %% [markdown]
# ### 2.2.4. Train the model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# create an instance
dtc_bot = DecisionTreeClassifier()

# fit your model
dtc_bot.fit(X_train, y_train)

# make predictions
preds = dtc_bot.predict(X_valid)

# evaluate on validation set
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.18797953964194372
#  Accuracy Score: 0.7838874680306905
#  Confusion Matrix:
#  [[550  75]
#  [ 94  63]]

# %% [markdown]
# # 3. MAKE PREDICTIONS
#
# Here, you will make predictions with the models that you have trained above.

# %% [markdown]
# ## 3.1. Predictions for Tweets (Political or Not)

# %%
#X = dfPoliticalAll_train[['num_political_entities','total_interactions','num_hashtags']]
#y = dfPoliticalAll_train['isPolitical'].apply(lambda x: 1 if x=='Yes' else 0)

X_train = dfPoliticalAll_train.select_dtypes(exclude=['object'])
#X = dfPoliticalAll_train[['is_reply', 'num_mentions', 'num_hashtags', 'num_retweets',
 #                         'num_favorites', 'num_political_entities', 'punctuation', 'is_verified']]
y_train = dfPoliticalAll_train['isPolitical'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
X_train.shape
# Out:
# (3994, 11)

# %%
from sklearn.preprocessing import StandardScaler
num_cols = X_train.select_dtypes(include=np.number).columns.tolist()

ss = StandardScaler()
X_train = pd.DataFrame(ss.fit_transform(X_train[num_cols]), columns=num_cols)

# %%
X_train
# Out:
#       is_retweet  is_reply  num_mentions  num_hashtags  num_retweets  \
# 0            0.0 -1.752528     -0.908933     -0.294296      3.708557
# 1            0.0 -1.752528     -0.908933     -0.294296      3.708557
# 2            0.0 -1.752528     -0.908933     -0.294296      3.708557
# 3            0.0 -1.752528     -0.908933     -0.294296      3.708557
# 4            0.0 -1.752528     -0.908933     -0.294296      3.708557
# ...          ...       ...           ...           ...           ...
# 3989         0.0  0.570604     -0.208107     -0.294296     -0.113063
# 3990         0.0 -1.752528      1.894370     -0.294296     -0.113063
# 3991         0.0  0.570604      1.193545     -0.294296     -0.113063
# 3992         0.0  0.570604     -0.208107     -0.294296     -0.113063
# 3993         0.0  0.570604      1.193545     -0.294296     -0.035071
#
#       num_favorites  num_political_entities  total_interactions  punctuation  \
# 0          0.896067               -0.515844            1.226528     1.372829
# 1          0.896067               -0.515844            1.226528     1.372829
# 2          0.896067               -0.515844            1.226528     1.372829
# 3          0.896067               -0.515844            1.226528     1.372829
# 4          0.896067               -0.515844            1.226528     1.372829
# ...             ...                     ...                 ...          ...
# 3989      -0.073192               -0.090342           -0.078573    -1.396869
# 3990      -0.073192                0.335160           -0.078573     0.449596
# 3991      -0.073192                1.186164           -0.078573     1.372829
# 3992      -0.073192               -0.941346           -0.078573    -0.473636
# 3993      -0.073192                1.611667           -0.069694    -1.396869
#
#       tweet_length  is_verified
# 0         0.973589    -0.135492
# 1         0.973589    -0.135492
# 2         0.973589    -0.135492
# 3         0.973589    -0.135492
# 4         0.973589    -0.135492
# ...            ...          ...
# 3989     -1.765145    -0.135492
# 3990      0.857541    -0.135492
# 3991      0.973589    -0.135492
# 3992     -1.347372    -0.135492
# 3993     -0.326149    -0.135492
#
# [3994 rows x 11 columns]

# %%
xgb_ros_p.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=60, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
X.shape
# Out:
# (3909, 16)

# %%
# read the evaluation file as follows

evaluationTweetDf = pd.read_csv(DATA_PATH+'evaluation-round{}-tweet.csv'.format(ROUND), dtype={0: str}, header=None, names=['tweet_id'])
evaluationTweetDf = evaluationTweetDf.dropna()
evaluationTweetDf

# merge it with the political dataframe so that you can use the make predictions based on the variables
dfPolitical_test = dfPolitical.merge(evaluationTweetDf)

# define X as we did above in section (2.x.2. Separate X and y values)
X = dfPolitical_test.select_dtypes(exclude=['object'])
ss = StandardScaler()
X = pd.DataFrame(ss.fit_transform(X[num_cols]), columns=num_cols)
# make predictions based on these variables
predictions_political = xgb_ros_p.predict(X)

# %%
predictions_political
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %% [markdown]
# ### This part is important! We expect you to return your predictions in the following format:

# %%
modelPredTweet = dict([(x,float(y)) for x,y in zip([*dfPolitical_test.tweet_id], predictions_political)])
modelPredTweet
# Out:
# {'1593649159009099777': 1.0,
#  '1367571642604544000': 0.0,
#  '1589993032975544320': 1.0,
#  '1565312596135354373': 1.0,
#  '1388235183653011462': 0.0,
#  '1592120408073203712': 1.0,
#  '1439547067337256967': 0.0,
#  '1597274845381029888': 1.0,
#  '1586021183958704128': 1.0,
#  '1356926480605982728': 1.0,
#  '1595357036925026306': 1.0,
#  '1585766233491886081': 1.0,
#  '1595871258985615361': 1.0,
#  '1352635736537882629': 1.0,
#  '1583477966373543936': 1.0,
#  '1564926450096013313': 1.0,
#  '1585634359612420101': 1.0,
#  '1384499047390658560': 0.0,
#  '1596583748669419521': 0.0,
#  '1391681495622995971': 0.0,
#  '1365710259549966339': 0.0,
#  '1590673118397624323': 0.0,
#  '1389951943343316995': 0.0,
#  '1407921226656280580': 0.0,
#  '1452348722810138646': 1.0,
#  '1597256187325878273': 0.0,
#  '1595829502021623812': 1.0,
#  '1579408398894137344': 1.0,
#  '1570758749606019073': 1.0,
#  '1366091745772077058': 0.0,
#  '1596233602886701057': 1.0,
#  '1584922292127256577': 0.0,
#  '1586279180983042050': 1.0,
#  '1399687111234756612': 0.0,
#  '1363226564683522051': 0.0,
#  '1596978345560150016': 1.0,
#  '1593686506622914560': 1.0,
#  '1424467918679597060': 0.0,
#  '1350478535954198530': 0.0,
#  '1375408516337389577': 1.0,
#  '1363883546637701121': 0.0,
#  '1547698793704960002': 1.0,
#  '1584612611160625152': 1.0,
#  '1593653522624643072': 1.0,
#  '1586647493152047104': 1.0,
#  '1561321365805883393': 1.0,
#  '1353277780465770502': 0.0,
#  '1441304592713601026': 0.0,
#  '1594271235260747776': 1.0,
#  '1595049063837229056': 0.0,
#  '1583499914990202880': 1.0,
#  '1595982622924197889': 1.0,
#  '1595871538712309760': 1.0,
#  '1393460176645144577': 1.0,
#  '1588924806279200768': 1.0,
#  '1552929917595226113': 0.0,
#  '1587422619829243905': 1.0,
#  '1553781925680226305': 1.0,
#  '1564065688762941440': 0.0,
#  '1592951246616678401': 0.0,
#  '1383095358536945667': 0.0,
#  '1388741087615913986': 0.0,
#  '1583746071205122048': 1.0,
#  '1563498679058649088': 1.0,
#  '1394780481045114885': 0.0,
#  '1346150249937711104': 0.0,
#  '1561345101305085957': 0.0,
#  '1596412648153059328': 1.0,
#  '1441844889134583808': 0.0,
#  '1417510101041176580': 0.0,
#  '1416778304452009984': 1.0,
#  '1598051085003857921': 1.0,
#  '1352726914398613504': 0.0,
#  '1380175362978680832': 0.0,
#  '1446449109997604865': 0.0,
#  '1366832249287622659': 0.0,
#  '1583368510306103296': 1.0,
#  '1592602720569286656': 1.0,
#  '1584540464224808960': 1.0,
#  '1561985072722583554': 1.0,
#  '1352717957911220226': 0.0,
#  '1579559691965038594': 1.0,
#  '1592017532151803904': 1.0,
#  '1347649378903875584': 0.0,
#  '1593110096045019136': 1.0,
#  '1595738052990828544': 1.0,
#  '1579854640392601600': 1.0,
#  '1596260609242595328': 1.0,
#  '1588193781031047168': 1.0,
#  '1595518151009124352': 1.0,
#  '1586093449287434240': 1.0,
#  '1586436277234114561': 1.0,
#  '1588321676323950593': 1.0,
#  '1544186612246003713': 1.0,
#  '1593561913761452032': 0.0,
#  '1400907711148089348': 0.0,
#  ...}

# %% [markdown]
# ## 3.2. Predictions for Users (Bot or Not)

# %%
X_train = dfBotAll_train.select_dtypes(exclude=['object'])
y_train = dfBotAll_train.isBot.apply(lambda x: 1 if x=='Yes' else 0)

# %%
from sklearn.preprocessing import StandardScaler
num_cols = X_train.select_dtypes(include=np.number).columns.tolist()

ss = StandardScaler()
X_train = pd.DataFrame(ss.fit_transform(X_train[num_cols]), columns=num_cols)

# %%
X_train.shape
# Out:
# (3909, 16)

# %%
X_train
# Out:
#       user_followers_count  user_friends_count  description_len  \
# 0                -0.106669           -0.181144        -0.772688
# 1                -0.106669           -0.181144        -0.772688
# 2                -0.047002            0.035492        -0.524441
# 3                -0.047002            0.035492        -0.524441
# 4                -0.047002            0.035492        -0.524441
# ...                    ...                 ...              ...
# 3904             -0.106041           -0.190649        -0.917498
# 3905             -0.105880           -0.167192        -0.917498
# 3906             -0.064325            0.257340         0.551294
# 3907             -0.107136           -0.194559        -0.379631
# 3908             -0.105091           -0.174628         2.309706
#
#       followers_to_all_ratio  user_protected  user_verified  user_geo_enabled  \
# 0                  -0.907499       -0.150874       -0.16203          1.326873
# 1                  -0.907499       -0.150874       -0.16203          1.326873
# 2                   0.908195       -0.150874       -0.16203          1.326873
# 3                   0.908195       -0.150874       -0.16203          1.326873
# 4                   0.908195       -0.150874       -0.16203          1.326873
# ...                      ...             ...            ...               ...
# 3904                0.831316       -0.150874       -0.16203         -0.753651
# 3905               -0.675394       -0.150874       -0.16203         -0.753651
# 3906                0.008365       -0.150874       -0.16203          1.326873
# 3907               -1.557601       -0.150874       -0.16203         -0.753651
# 3908                0.053603       -0.150874       -0.16203          1.326873
#
#          since  user_tweet_count  user_fav_count  average_tweet  average_fav  \
# 0    -0.911696         -0.312182       -0.261804      -0.368987     0.105576
# 1    -0.911696         -0.312182       -0.261804      -0.368987     0.105576
# 2    -0.676057          0.207421       -0.288974       0.720860    -0.201688
# 3    -0.676057          0.207421       -0.288974       0.720860    -0.201688
# 4    -0.676057          0.207421       -0.288974       0.720860    -0.201688
# ...        ...               ...             ...            ...          ...
# 3904 -0.643740         -0.276823       -0.413928      -0.348448    -0.426667
# 3905 -1.222067         -0.341121       -0.477485      -0.349248    -0.468304
# 3906  0.334499         -0.331845       -0.470958      -0.479667    -0.530440
# 3907 -1.139929         -0.344906       -0.479435      -0.487815    -0.532133
# 3908 -0.839658         -0.252574       -0.429241      -0.208157    -0.412741
#
#       count_digits  retweet_total_ratio  num_median_favorites  num_of_tweets
# 0         0.565100             0.116444             -0.075984       0.256128
# 1         0.565100             0.116444             -0.075984       0.256128
# 2        -0.633693            -0.647979             -0.075984       0.323903
# 3        -0.633693            -0.647979             -0.075984       0.323903
# 4        -0.633693            -0.647979             -0.075984       0.323903
# ...            ...                  ...                   ...            ...
# 3904      0.964698            -1.000652             -0.067039       0.323903
# 3905     -0.633693             0.635751             -0.075984       0.323903
# 3906     -0.633693            -0.887797              0.246019       0.323903
# 3907      0.165502             1.169643             -0.075984      -3.900772
# 3908     -0.234095            -0.873690             -0.067039       0.323903
#
# [3909 rows x 16 columns]

# %%
adb_ros.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=250)

# %%
evaluationUserDf = pd.read_csv(DATA_PATH+'evaluation-round{}-user.csv'.format(ROUND), dtype={0: str}, header=None, names=['user_screen_name'])
evaluationUserDf = evaluationUserDf.dropna()

# merge it with the political dataframe so that you can use the make predictions based on the variables
dfBot_test = dfBotAll.merge(evaluationUserDf)

# define X as we did above in section (2.x.2. Separate X and y values)
X = dfBot_test.select_dtypes(exclude=['object'])
ss = StandardScaler()
X = pd.DataFrame(ss.fit_transform(X[num_cols]), columns=num_cols)
# make predictions based on these variables
predictions_bot = adb_ros.predict(X)

# %%
X.shape
# Out:
# (5000, 16)

# %%
modelPredUser = dict([(x,float(y)) for x,y in zip([*dfBot_test.user_screen_name], predictions_bot)])
modelPredUser
# Out:
# {'nedenburdaysam': 0.0,
#  'biologselim': 0.0,
#  'alaraaynncnm': 0.0,
#  '_sydneycarton_': 0.0,
#  'denizlihabercom': 0.0,
#  'burakerbaychp': 0.0,
#  'mustafaarst': 0.0,
#  'mvnez': 0.0,
#  'qara118': 0.0,
#  'alpar_kaan': 0.0,
#  'farukhalit2': 0.0,
#  'haf_zhan': 0.0,
#  'harlunoshi': 0.0,
#  'heritagepaix': 0.0,
#  '37baho37': 0.0,
#  'tamerduran_1': 0.0,
#  'donkisotumsu': 0.0,
#  'nuranwolf': 0.0,
#  'politikgundem': 0.0,
#  'isakethudax': 0.0,
#  'ilaydejaneiro': 0.0,
#  'gendenmukatol': 0.0,
#  '1905anason': 0.0,
#  'eraydurgut03': 0.0,
#  'dasiskein': 0.0,
#  'mett_1907': 0.0,
#  'semihyeteer': 0.0,
#  'haberinyokcokk': 0.0,
#  'meleky_ozaydin': 0.0,
#  'han34nesli': 0.0,
#  'bilobi4': 0.0,
#  'berkeduranovic': 0.0,
#  'cagdasadim': 0.0,
#  'merabalare': 0.0,
#  'sevdaac72373936': 1.0,
#  '21gramlife1': 0.0,
#  'cakan0_': 0.0,
#  'oguzksalici': 0.0,
#  'emre_caliskann': 0.0,
#  'mehmet07454846': 0.0,
#  'lifegs': 0.0,
#  'begumkarabeyx': 0.0,
#  'avutulan': 0.0,
#  'imamgibiimam': 0.0,
#  'durdane52': 0.0,
#  'radyotrafik35': 0.0,
#  'rk_ozanyali': 0.0,
#  'uykusuz75': 0.0,
#  'goksubayy': 0.0,
#  'ilgihaber': 0.0,
#  'samobisus': 0.0,
#  'iddaaalkc': 0.0,
#  'nnnccdd': 0.0,
#  'iskndr0935': 0.0,
#  'gknilg': 0.0,
#  '_simurg1_': 0.0,
#  'lasmananaskiss': 0.0,
#  'berhanataoglu': 0.0,
#  'alicemalakgl1': 0.0,
#  'denizaydemirchp': 0.0,
#  'sevdesensoz': 0.0,
#  'uortaogretim': 0.0,
#  'matiasemilio19': 0.0,
#  'furkanakinbjk': 0.0,
#  'altinhakan': 0.0,
#  'chpfotograf': 0.0,
#  'ibuzgan': 0.0,
#  'snurgo': 0.0,
#  'selincivali': 0.0,
#  'akgencbagcilar': 0.0,
#  'tayyarturkes': 0.0,
#  'nefiorii': 0.0,
#  'turan_3460_': 0.0,
#  'yavuztellioglu': 0.0,
#  'feyyzatemeltas': 0.0,
#  'dr_sozdemir': 0.0,
#  'gulden_girgin': 0.0,
#  'n11comdestek': 0.0,
#  'vkooktime': 0.0,
#  'mikailavc13': 0.0,
#  'maveravakfi': 0.0,
#  'meftuniyet': 0.0,
#  'aygultoni': 0.0,
#  'melihaakyol77': 0.0,
#  'asikkutluserkan': 0.0,
#  'yorgun_anney': 0.0,
#  'ozkancvs': 0.0,
#  'bakhelebak': 0.0,
#  'bahargelecek123': 0.0,
#  'muzaffermuzzy49': 0.0,
#  'qquazarr': 0.0,
#  'zgrlknegzel1': 0.0,
#  'primiti16830778': 0.0,
#  'mertgng49257897': 0.0,
#  'aydan_gedik6': 1.0,
#  'maltepeakparti': 0.0,
#  'szqeswa': 0.0,
#  'isaal1': 0.0,
#  'safaktun1': 0.0,
#  'hikimse10392188': 0.0,
#  'benigermeeyin': 0.0,
#  'cakirkeyif1903': 0.0,
#  'mnurpol': 0.0,
#  'siddeteson2': 0.0,
#  'coffelers17': 0.0,
#  'tubiiiissss': 0.0,
#  'binnazatma': 0.0,
#  'aysegul2712': 0.0,
#  'cerrahdrmurat': 0.0,
#  'mustafapolatist': 0.0,
#  'recepgnt': 0.0,
#  'tduygukultur': 0.0,
#  'troublebuse': 0.0,
#  'arzuerdemdb': 0.0,
#  'yinemihakkli': 0.0,
#  'alioktaydereci': 0.0,
#  'mvp_1030': 0.0,
#  'mudiclk01': 0.0,
#  'dhainternet': 0.0,
#  'birsen_birgul': 0.0,
#  'vbozkurt55': 0.0,
#  'murat_kurum': 0.0,
#  'tinywangxian': 0.0,
#  'radtek43770356': 0.0,
#  'ssairaoml': 0.0,
#  'daysoldier': 0.0,
#  'ldtasdelen': 0.0,
#  'trtradyo1': 0.0,
#  'free_archi': 0.0,
#  'resmihaberler': 0.0,
#  'hasansonmez77': 0.0,
#  'emirssenol': 0.0,
#  'eyzira': 0.0,
#  'globalkripto1': 0.0,
#  'umutnimetatas': 0.0,
#  'bulentsanverchp': 0.0,
#  'vidacitigris': 0.0,
#  'noluyoruya': 0.0,
#  'bisakinol_1881': 0.0,
#  'sevalkayan01': 0.0,
#  'nimetssevimtr': 1.0,
#  'hasankocatepe26': 0.0,
#  'f_dont': 0.0,
#  'valisu31': 0.0,
#  'frat22880933': 0.0,
#  'haber_ortami': 1.0,
#  'eminegkrr': 0.0,
#  'taibosman': 0.0,
#  'nkomakhos': 0.0,
#  'alipeker1903': 0.0,
#  'kazimsarican': 0.0,
#  'pyrzca': 0.0,
#  'turkan__ay': 0.0,
#  'sametsettt': 0.0,
#  'onurkirac01': 0.0,
#  'oakziner': 0.0,
#  'kingofthebjk': 0.0,
#  '__ebedmuddet__': 0.0,
#  'aydoganali68': 0.0,
#  'umtbaykal': 0.0,
#  'endersarilacvrt': 0.0,
#  'semihates43': 0.0,
#  'ilkmp3': 0.0,
#  'babai1235': 0.0,
#  'nursse_hemsire': 0.0,
#  'hamitpicak46': 0.0,
#  'captzulu737': 0.0,
#  'refikdartici': 0.0,
#  'aliefeuygun': 0.0,
#  'ugur_tarhan': 0.0,
#  'yiyotekin': 0.0,
#  'ludwigplanckk': 0.0,
#  '34feyzu': 0.0,
#  'firatyurdakul': 0.0,
#  'rserkant': 0.0,
#  'serkanyardim': 0.0,
#  'openaichattr': 0.0,
#  'ay47729837': 0.0,
#  'tbatmaz2': 0.0,
#  'yavuzz65': 0.0,
#  'starlightd0': 0.0,
#  'alfredofoot': 0.0,
#  'yagclut': 1.0,
#  'gezsed': 0.0,
#  'nurdino7': 0.0,
#  'iyusufturanli': 0.0,
#  'tvnet': 0.0,
#  'muzafferburann': 0.0,
#  'muziksever00': 0.0,
#  'aveonjcom': 0.0,
#  'utikitiki': 0.0,
#  'bugan_hac': 0.0,
#  'gloryjadey': 0.0,
#  'zaferisik016': 0.0,
#  'semioticus': 0.0,
#  'dumendenhaydar': 0.0,
#  'ykiranoglu': 0.0,
#  'furkicanab': 0.0,
#  'fatihya45929940': 0.0,
#  'hsnkaratas1907': 0.0,
#  'macovskiii': 0.0,
#  'uerdovan': 0.0,
#  'berat92266271': 1.0,
#  'kvseryyla': 0.0,
#  'waspazy': 0.0,
#  'eneskaanylmz': 0.0,
#  'volkanipek32': 0.0,
#  'ezgiekincelik1': 0.0,
#  'turizmgazete': 0.0,
#  'mer06666': 1.0,
#  'su_pinari': 0.0,
#  'denisinbiri': 0.0,
#  '_adnansaruhan_': 0.0,
#  'timbooth75': 0.0,
#  'mustafhaaaa': 0.0,
#  'ossurukboceki': 0.0,
#  'yunusbozkuurt': 0.0,
#  'aksakal_memet': 0.0,
#  'iyiozgurozyurt': 0.0,
#  'isa_ozguller': 0.0,
#  'baraan56': 0.0,
#  'aftiel86': 0.0,
#  'mygazeteantalya': 0.0,
#  'cemile_cetiner': 0.0,
#  'mehmetmert70': 0.0,
#  'ulayoezer': 0.0,
#  'gokcegokcen_': 0.0,
#  'aaltuntas70': 0.0,
#  'umayy1907': 0.0,
#  'siyaaydin': 0.0,
#  'v1ens14': 0.0,
#  'samueljsdv': 1.0,
#  'chpuskgenclik': 0.0,
#  'arpacikcihat': 0.0,
#  'kksalseyfullah': 0.0,
#  'miirac0909': 0.0,
#  'alicecrn': 0.0,
#  'ozleemcelk': 0.0,
#  'avemrekptnoglu': 0.0,
#  'mehmetburgac1': 0.0,
#  'ahmetayhan99': 0.0,
#  'osmanakgul29': 0.0,
#  'yusufberk06': 0.0,
#  'hibakkus': 0.0,
#  'tallman93409915': 0.0,
#  'hektor5734': 0.0,
#  'isimsizisim123': 0.0,
#  'sudekafal': 0.0,
#  'uzunnman': 0.0,
#  'emotivasyon': 0.0,
#  'alimutum1964': 0.0,
#  'asliarslaan': 0.0,
#  'mustafa_destici': 0.0,
#  'savunmasanayist': 0.0,
#  'prenses_show': 1.0,
#  'foamofthedaze': 0.0,
#  'osman_aygunn': 0.0,
#  'canernevermind': 0.0,
#  'yalcingg': 0.0,
#  'gundemedairhs': 0.0,
#  'birkomikpanda': 0.0,
#  'tolgahankaya0': 1.0,
#  'iamcansun': 0.0,
#  'hseyink42305996': 0.0,
#  'enastaenistera': 0.0,
#  'mminbicil2': 0.0,
#  'sceleboglu': 0.0,
#  'gokhanmirall': 0.0,
#  'ibrahimkoray28': 0.0,
#  'ayemyasin': 0.0,
#  'kardii2424': 0.0,
#  'nurkanmaz2': 0.0,
#  'imeratarot': 0.0,
#  'aryaaryastark11': 0.0,
#  'abetulkayahan': 0.0,
#  'enhakikimursid': 0.0,
#  'celebimehmeta': 0.0,
#  'erenicooo34': 0.0,
#  'huseyin14330438': 0.0,
#  'agdtv': 0.0,
#  'azatepe': 0.0,
#  'msen5885': 0.0,
#  'lebron2_king': 0.0,
#  'nesrinaras141': 1.0,
#  'muratzaknc1': 0.0,
#  'mesutmustafaak2': 0.0,
#  'ysametiscii': 0.0,
#  'muallarenksiz': 0.0,
#  'restlessschild': 0.0,
#  'avmehmetozkan1': 0.0,
#  'aykutsafakkayaa': 0.0,
#  'hatiec1209': 0.0,
#  'nurhayatesmaa': 1.0,
#  'murathanmhp': 0.0,
#  'seeutmrrw': 0.0,
#  '8lampardd': 0.0,
#  'kaan_blky': 0.0,
#  'cicek321471': 0.0,
#  'smailorak10': 0.0,
#  'tplgll': 1.0,
#  'ezo05264399': 1.0,
#  'bl4ckp1nk97': 0.0,
#  'izmilli19': 0.0,
#  'drmetinilhan40': 0.0,
#  'tubataserr': 0.0,
#  'kaanboz10993308': 1.0,
#  'boragulpinar': 0.0,
#  'haberinizcomtr': 0.0,
#  'tekirdaghatice': 1.0,
#  'm_songulalp': 0.0,
#  'almilapars2': 0.0,
#  'yasinucantr': 0.0,
#  'tmsymustafa': 0.0,
#  'iyiamanedenyani': 0.0,
#  'cengiz1bey': 0.0,
#  'tmrosmanagaoglu': 0.0,
#  'brcukocaa': 0.0,
#  'mustafa_yalcin2': 0.0,
#  'hanifekrcdemir': 0.0,
#  'aryaates10': 1.0,
#  'd3n1z1n_k1z1': 0.0,
#  'senidesavunurum': 0.0,
#  'birarmaugrunaa': 0.0,
#  'emrahadakli': 0.0,
#  'adige_turan': 0.0,
#  'tknnnur': 0.0,
#  'knstntndeluu': 0.0,
#  'dilekkat1': 1.0,
#  'rdvntrkylmz': 0.0,
#  'izelbydn': 0.0,
#  'sevilaynalbant1': 0.0,
#  'bilgekazan02': 0.0,
#  'bizesoruntv': 0.0,
#  'feydem003': 1.0,
#  'bkrhly0803': 0.0,
#  'alleynaa16': 0.0,
#  'osanmaz_kaya': 0.0,
#  'sunflower1823': 0.0,
#  'kwmitchi': 0.0,
#  'muratdu68243139': 0.0,
#  'm_tumer': 0.0,
#  '01_murat_80': 0.0,
#  'melike1234567': 0.0,
#  'tribunnsozluk': 0.0,
#  'j_j_o_10': 0.0,
#  'baliskonuz': 0.0,
#  'ozantur33802030': 0.0,
#  'thelady_mi': 0.0,
#  'oncesiwesonrasi': 1.0,
#  'sunasefer': 0.0,
#  'drosedawson_': 0.0,
#  'akilfikirparti': 0.0,
#  'laylabesiroglu': 0.0,
#  'ansuh1995': 1.0,
#  'sleyman59570757': 1.0,
#  'kocagolali': 0.0,
#  'mhmettedebiyat': 0.0,
#  'mustafa043yedek': 0.0,
#  'ylmzrmz': 0.0,
#  'nurluv1': 1.0,
#  'mhmt_dnmez': 0.0,
#  'isilozcan434': 1.0,
#  'karizma7583_': 0.0,
#  'muammergokcin': 0.0,
#  '1mirzabey': 0.0,
#  'hln_sbs94': 0.0,
#  'chpyemevzu': 0.0,
#  'stajzedenur': 1.0,
#  'socarofficial': 0.0,
#  'smeyye54030601': 1.0,
#  'mdogan80': 1.0,
#  'hasanlal18': 0.0,
#  'aynurr82444477': 0.0,
#  'engindalbast': 0.0,
#  'cevapsiztweet': 0.0,
#  'yuzlasma': 1.0,
#  'vethekbusra': 0.0,
#  'yilmaz_dagdelen': 0.0,
#  'cybermigren': 0.0,
#  'ayyldz38106604': 1.0,
#  'secimlegeldik': 0.0,
#  'hiciiknoktasi': 0.0,
#  'hfzfehmitufan': 0.0,
#  'edinrose5': 0.0,
#  'harunzk45625173': 1.0,
#  'rt_sag1': 1.0,
#  'nesfrit1': 0.0,
#  'meraltan_': 0.0,
#  'feedanhsynli': 0.0,
#  'cuvalogluberkay': 0.0,
#  'turan5801': 0.0,
#  'kimyacibaba1': 0.0,
#  'oxlade25': 0.0,
#  'dorarafa': 0.0,
#  'aydinvaliligi': 0.0,
#  'sevgierol759': 0.0,
#  'deplasmancom': 0.0,
#  'kellecimehmet58': 0.0,
#  'merym2y': 0.0,
#  'mrtkaan5': 0.0,
#  'eminmalazgirt': 0.0,
#  'dilekreelforex': 0.0,
#  'abbas0784': 0.0,
#  'yildirimoztug': 0.0,
#  'gracenewbie': 0.0,
#  'f_ratdemirci': 1.0,
#  'nebi_arda_': 0.0,
#  'eray91576993': 0.0,
#  'meyaschoice': 0.0,
#  'reeltemizlik1': 0.0,
#  'supertolkstolk': 0.0,
#  'bugraa_hann': 0.0,
#  'ishak5334': 0.0,
#  'blueberyboi': 0.0,
#  'malefiziii': 0.0,
#  '81_karacahil': 0.0,
#  'txfrtdy': 1.0,
#  'ewremmm52': 0.0,
#  'bayrakvatan34': 0.0,
#  'bravextr': 0.0,
#  'jeneriklikpas': 0.0,
#  'nejla188136991': 1.0,
#  'somewhere9s': 0.0,
#  'izim62': 0.0,
#  'kayanadnah': 1.0,
#  'hayri8383': 1.0,
#  'demirness02': 1.0,
#  'mrynr4': 0.0,
#  'minikbelanzz': 0.0,
#  'hasan_killik': 0.0,
#  'tukul46': 0.0,
#  'wolfofwst1907': 0.0,
#  'ccbiazin': 0.0,
#  'ozenhlc': 0.0,
#  'yektaorkuncelik': 0.0,
#  'ayhaneroglu14': 1.0,
#  'ensdndr1': 0.0,
#  'maynameserpil': 0.0,
#  'marti141216': 0.0,
#  'nurayshine': 0.0,
#  'mustafayel59': 0.0,
#  'serdaraydinnn': 0.0,
#  'papatya84595001': 1.0,
#  'cazhareketi': 0.0,
#  'myildirim_06': 0.0,
#  'inleyerek31': 0.0,
#  'hicran33880494': 0.0,
#  'adem_ahmet': 1.0,
#  'iyi_kus': 0.0,
#  'arikanmucahit32': 0.0,
#  'm_cicekdagi32': 0.0,
#  '44hakan34': 0.0,
#  'ers25936353': 1.0,
#  'yalan__zaman': 0.0,
#  'erbaturdeniz': 0.0,
#  'veyseldayan65': 0.0,
#  'sencerbeyyyy': 1.0,
#  'akavutoglu': 0.0,
#  'tahsin87664169': 0.0,
#  'cansufcbmg': 0.0,
#  'bora_ares': 0.0,
#  'alkanokuducu': 0.0,
#  '18eren': 0.0,
#  'aysesibelersoy': 0.0,
#  's010335835191': 0.0,
#  'hilcoban': 0.0,
#  'muhyittinaltun1': 0.0,
#  'halukkunuk1970': 0.0,
#  'ua_mehmety_gs': 0.0,
#  'nmmachiavelli': 0.0,
#  'neziraltan4': 1.0,
#  'murat03814297': 0.0,
#  'difuruz': 0.0,
#  'wineteamo': 1.0,
#  'seldaakgun36': 0.0,
#  'baris01451930': 0.0,
#  'suathayri8': 0.0,
#  'ayea98437004': 1.0,
#  'sensoyle_1': 0.0,
#  'ejderbit': 0.0,
#  'guraytturkoglu': 0.0,
#  'turguttunc34': 0.0,
#  'emrksk81': 1.0,
#  'kocakvahit': 0.0,
#  'fercu22': 0.0,
#  'askerr01': 1.0,
#  'zeyirsoylu4': 0.0,
#  'liderimrte2023': 1.0,
#  'semoswebster': 0.0,
#  'ddionysos_s': 0.0,
#  'lutfikasikci': 0.0,
#  'turk_texas': 0.0,
#  'nalcieslem': 0.0,
#  'havanur_3442': 0.0,
#  'tenkyuverima': 0.0,
#  'bek_mirzo23': 0.0,
#  'rd3622': 0.0,
#  'muhammetummunfs': 1.0,
#  'bsmedya': 0.0,
#  'seyyah2011': 0.0,
#  'selcuk64493163': 0.0,
#  'myzc88': 0.0,
#  'esgaldhor': 0.0,
#  'rego97687151': 0.0,
#  'elbasrisenn': 0.0,
#  'ali86626921': 0.0,
#  'sekulerme': 0.0,
#  'jiskenderoglu': 0.0,
#  'demir342734': 0.0,
#  'lanetfederal9': 0.0,
#  'marlboroliightt': 0.0,
#  'rakisaati': 0.0,
#  'ferhandemir25': 1.0,
#  'fuatoze2': 0.0,
#  'muzaffe1971': 0.0,
#  'madak71': 0.0,
#  'asparagas08': 0.0,
#  'miyaavvs': 0.0,
#  'gultenbacaks': 1.0,
#  'hera_74': 0.0,
#  'targetvienna': 0.0,
#  'mustafademirok5': 1.0,
#  'eminedali': 0.0,
#  'vdreamergrey_': 0.0,
#  'zcan43809267': 0.0,
#  '7reporter': 0.0,
#  'mhmtcnkrgl1': 0.0,
#  'hakanarol': 0.0,
#  'turan_ordusu53': 1.0,
#  'damllasenn': 0.0,
#  'batcao': 0.0,
#  'qaa52815672': 0.0,
#  'myruh34': 0.0,
#  'nurcugdso': 0.0,
#  'ayenur656431111': 0.0,
#  'melimisss': 0.0,
#  'dgnalirza': 0.0,
#  'hseyinyzbaolu31': 0.0,
#  'akgenclikmus': 0.0,
#  'redrojo76665196': 0.0,
#  'gokseelgok': 0.0,
#  'sahabettin_sebe': 0.0,
#  'umutisigiii': 0.0,
#  'sahsenem_s': 0.0,
#  'leonamelzo': 0.0,
#  'mkarakuzu3': 1.0,
#  'excalibur34tr': 0.0,
#  'mercedesbeyz': 0.0,
#  'haticedemirer13': 0.0,
#  'nilovalii': 0.0,
#  'gurbuzyurdanur': 0.0,
#  'ismailozkantv': 0.0,
#  '__yel__iz__': 0.0,
#  'furkandenizv': 0.0,
#  'gabymenta': 0.0,
#  'plutonluur_': 0.0,
#  'ahmet42359666': 0.0,
#  'samettdonmezz': 0.0,
#  'mehmet_arzu21': 0.0,
#  'chicoofresaa': 0.0,
#  'polatgokhan72': 0.0,
#  'uuttkuuu1': 0.0,
#  'suskun_ca': 0.0,
#  'pelinso19646937': 0.0,
#  'skaantopaloglu': 0.0,
#  'yusufozel50': 0.0,
#  'sadecekaravaris': 0.0,
#  'mehmete23916590': 0.0,
#  'ertugrulhasa': 1.0,
#  'ebuhurma_bin71': 0.0,
#  'aalparslandogan': 0.0,
#  '4646kkk': 0.0,
#  'hasan48527150': 1.0,
#  'mrpetit03': 0.0,
#  'yakup_tac': 1.0,
#  'aygannizamettin': 0.0,
#  'akiffydn54': 0.0,
#  'huseyindagteki8': 0.0,
#  '_ys33': 0.0,
#  'kapakedebiyati': 0.0,
#  'psychedelicmega': 0.0,
#  'anittepemah': 1.0,
#  'eruilivatar': 0.0,
#  'rahan78614563': 0.0,
#  'alsacselahattin': 0.0,
#  'nessybabysi': 0.0,
#  'azizdortler': 0.0,
#  '1903cakmakoglu': 0.0,
#  'neocaesarean': 0.0,
#  'farukel27207281': 1.0,
#  'tckemal59451041': 0.0,
#  'elifhalilsunar': 0.0,
#  'referansgazetes': 0.0,
#  'vodkaliborek': 0.0,
#  'eagleselmann': 0.0,
#  'muazzezkarakuz1': 1.0,
#  'alinuraktas70': 0.0,
#  'analizlerle': 0.0,
#  'xymemyan': 0.0,
#  'serpil69937590': 1.0,
#  'meemoolii07': 0.0,
#  'ucanlarinozguru': 0.0,
#  'temoootemooo1': 0.0,
#  'llbusrra': 0.0,
#  'mihrimahgundogd': 1.0,
#  'ezgii22e': 0.0,
#  'empathy1069': 0.0,
#  'abdullahdmr5234': 0.0,
#  'nenehatun252525': 0.0,
#  '52ellianti': 1.0,
#  '06murat40': 0.0,
#  'muhdsumar': 0.0,
#  'radyolojitgt11': 0.0,
#  '100binatamahak': 1.0,
#  'kuzenraven': 0.0,
#  'herkann': 0.0,
#  '_emel_iskender_': 0.0,
#  'mehmetaktass42': 0.0,
#  'mehmetcalik1903': 0.0,
#  'iyi_psikoloji': 0.0,
#  'rahmikangal8181': 0.0,
#  'ispahaergun': 0.0,
#  'sir_gala': 0.0,
#  'onder_1881': 1.0,
#  'aglamicamaglami': 0.0,
#  'der__en': 1.0,
#  'c_keper': 0.0,
#  'barisustunbas34': 0.0,
#  '81subat': 0.0,
#  'cifri77': 0.0,
#  'phoenixsnm': 0.0,
#  'mehmettoprakk55': 0.0,
#  'aysun_becek': 1.0,
#  'ahmetckarali': 0.0,
#  '123ciklet': 0.0,
#  'akkadinbeykoz': 0.0,
#  'mehvesdemirer': 0.0,
#  'gazetemuz': 0.0,
#  'tevfikozgul': 0.0,
#  'oyablsl': 0.0,
#  'atam02': 0.0,
#  'jamesblacklol': 0.0,
#  'shnhuri': 0.0,
#  'cananyslyrt98': 0.0,
#  'milanbarosizm': 0.0,
#  'y35936059': 1.0,
#  'sungurogiu': 0.0,
#  'ilhan29914305': 1.0,
#  'tbugradayi': 0.0,
#  'muammerelk4': 0.0,
#  'sedefbostan1': 1.0,
#  'yunuserkul9': 1.0,
#  'bouquet_buket': 0.0,
#  'ahmetkurolu1': 0.0,
#  'sofuatar1': 0.0,
#  'duygu44655629': 0.0,
#  'alican69969774': 0.0,
#  'oyumchpye': 0.0,
#  'eliscilik': 0.0,
#  'httopal': 0.0,
#  'akgulhasan62': 0.0,
#  'cevahir_tolga': 0.0,
#  'byunlipsloey': 0.0,
#  'metaverse_promt': 0.0,
#  'rmzsulo': 0.0,
#  'ceredipity': 0.0,
#  'aliyletivitce': 0.0,
#  'erolylmz020': 0.0,
#  'venividiperivi': 0.0,
#  'baharmtumer': 0.0,
#  'cumhuriyetgzt': 0.0,
#  'seyfullahaslan': 0.0,
#  'naobad94': 0.0,
#  'mucellapakdemir': 0.0,
#  'monoclockth': 0.0,
#  'abdullahcinsul1': 1.0,
#  'istinye_yokusu': 0.0,
#  'hakkitaruz': 0.0,
#  'bbpbyrmpsresmi': 0.0,
#  'etkinlikatma': 0.0,
#  'santiagonowcast': 0.0,
#  'bilalhotmailco6': 0.0,
#  'kemalaydomu11': 0.0,
#  'mehmeta17853051': 1.0,
#  'constantinapolx': 0.0,
#  'fuckleroykendal': 0.0,
#  'altanbostanci': 0.0,
#  'nurlu_hnn': 0.0,
#  'mafazannakk': 0.0,
#  'osman5138': 0.0,
#  'nebi_nuh': 0.0,
#  'robingstz': 0.0,
#  '_forever_1903': 0.0,
#  'rebercn': 0.0,
#  'sevgiorc': 1.0,
#  'prvszakrep': 0.0,
#  'metehannn_8': 1.0,
#  'tonygozet': 0.0,
#  'dndr_ztrk': 0.0,
#  'karslan17': 0.0,
#  'yuksekova_m': 0.0,
#  'ahaistebu': 0.0,
#  'seyma_btl_': 0.0,
#  'avhaticeyldz': 0.0,
#  'adinna__': 0.0,
#  'a82317335aslan': 1.0,
#  'bozkurt_dogan1': 0.0,
#  'kyaegunn': 0.0,
#  'epiphanlarity': 0.0,
#  'huseyin_agars': 0.0,
#  'izzet_besevli78': 0.0,
#  'insaneautor': 0.0,
#  'baweraunnehir': 0.0,
#  'zekikar46878782': 1.0,
#  'foraorg': 0.0,
#  'levent28939983': 0.0,
#  'seherbirinciii': 0.0,
#  'muslumbaba25': 0.0,
#  'dniigeria': 0.0,
#  'ahmetdoan011': 0.0,
#  'kerem84242180': 0.0,
#  'fenersonhaber': 0.0,
#  'dedeoglusakir': 0.0,
#  'serseriyimsenle': 0.0,
#  'nisebinciyager': 0.0,
#  'noyanayra': 0.0,
#  'yildirimsamii': 0.0,
#  'muserrefkargi': 0.0,
#  'dipsiz1kuyu7': 0.0,
#  'sevda78899': 1.0,
#  'serhatkozturks': 0.0,
#  'mustafa__kynk': 0.0,
#  'masmakut': 0.0,
#  'koksal87889937': 0.0,
#  'huseyin70502807': 0.0,
#  'kuzey1800': 1.0,
#  'cebrailtemel52': 0.0,
#  'aysen_yldrm_': 0.0,
#  'busraurr': 0.0,
#  'fulyasimsekcakr': 0.0,
#  'cuma06235351': 1.0,
#  'fatihsu145323': 0.0,
#  'timucin3406': 0.0,
#  'darkes_48': 0.0,
#  'ebeamaatanamadi': 0.0,
#  'ismetah04165791': 0.0,
#  'adalethak6': 1.0,
#  'aslankralist': 0.0,
#  'prince__raji': 0.0,
#  'kddrummondnfl': 0.0,
#  'furkanblenterd1': 0.0,
#  'ferhanxyz': 0.0,
#  'zorunlucografya': 0.0,
#  'ddurust2': 0.0,
#  'yazdikanka': 0.0,
#  'songul___2023': 1.0,
#  'irfan_girgin_': 0.0,
#  'ahmetsenal1': 0.0,
#  'hunilisaphiens': 0.0,
#  'promo_togo': 0.0,
#  'memetuar18': 0.0,
#  'gkhan989793831': 0.0,
#  'bbisekreter1': 0.0,
#  '_saituk_': 0.0,
#  'pandoraninkoli': 0.0,
#  'kemalolu6': 0.0,
#  'brahim04798715': 0.0,
#  'serkanksoz': 0.0,
#  'yedinchss': 0.0,
#  'umkumuncuk': 0.0,
#  'adelante_d': 0.0,
#  'maviasi17': 0.0,
#  'huzur098712': 0.0,
#  'kenan_kiran': 0.0,
#  'ozelsakura': 0.0,
#  'mel75801': 0.0,
#  'turktur_ozum': 0.0,
#  'noavasblog': 0.0,
#  'smr_plt_': 0.0,
#  'tr_whitestar': 0.0,
#  'bekirgonenn': 0.0,
#  'sebo_1963': 0.0,
#  'sananelantospik': 0.0,
#  'unalcevikoz': 0.0,
#  'metehansahiiiin': 0.0,
#  'kocdevrim01': 0.0,
#  'turizmhabermrk': 0.0,
#  'magnofrancklin': 0.0,
#  'cagricantopcu': 0.0,
#  'karakus_aylak': 0.0,
#  'jossalove24': 1.0,
#  'eczhatice07': 0.0,
#  'jonginimio': 0.0,
#  'smalylmaz12': 1.0,
#  'alperrustem': 0.0,
#  'korezincom': 0.0,
#  'demetswife': 0.0,
#  'efe25454822': 1.0,
#  'dirwongkarwai': 0.0,
#  'merve_trh93': 0.0,
#  'yenisolukcom': 0.0,
#  'semihsamet1919': 0.0,
#  'anataeus': 1.0,
#  'kemeroglu_ctn': 0.0,
#  'kucukdunyatr': 0.0,
#  'ekobey37': 0.0,
#  'imparator2569': 0.0,
#  'alimahir': 0.0,
#  'politic_tr': 0.0,
#  'oglu_macarl': 0.0,
#  'ismailttpaloglu': 0.0,
#  'edizyil47765465': 0.0,
#  'ozancankemal': 0.0,
#  'hardtoliveya': 0.0,
#  'chilizkolik': 0.0,
#  'm_eminozdemir33': 0.0,
#  'tarihogretmeni6': 1.0,
#  'kazimkarabek5': 0.0,
#  'brkbarbarosoglu': 0.0,
#  'ahmet_oylek': 0.0,
#  'ahfalandunya': 0.0,
#  'fatihkaraveli61': 0.0,
#  'feyselsimsek': 0.0,
#  'kamudaii1': 0.0,
#  'denizzzz1234': 0.0,
#  'nrdnkle': 0.0,
#  'vefakarguvenlik': 1.0,
#  'ayaz043043': 1.0,
#  'gamze06759975': 0.0,
#  'dilek_sozdarrr': 0.0,
#  'kidsnlo': 0.0,
#  'k971689': 0.0,
#  '28ekim1926': 0.0,
#  'birgazetecom': 0.0,
#  'bibercizehra': 0.0,
#  'ademyrtmen': 0.0,
#  'blueandpurple61': 0.0,
#  'msdegngr07': 0.0,
#  'acikistihbarat': 0.0,
#  'agirmanibrahim': 0.0,
#  'meribasgeri': 0.0,
#  'genclikhasan': 0.0,
#  'edebiyatci_96': 1.0,
#  'du35518218duman': 1.0,
#  'ucankuslarxd': 0.0,
#  'yasemin_busrayy': 0.0,
#  'nihatbuyukbayr1': 0.0,
#  'ttaynaralimaa': 0.0,
#  'gaffarmudur34': 0.0,
#  '2020kpss202020': 1.0,
#  'mrscelikbilek': 0.0,
#  'anadoluatesi36': 0.0,
#  'koftianan': 0.0,
#  'krklm': 1.0,
#  'mnreelk1': 1.0,
#  'mimarastr': 0.0,
#  'taseronsa': 1.0,
#  'ifsaci_abi33': 0.0,
#  'sfrsml': 0.0,
#  'denizsuyu61': 0.0,
#  'alban_idris': 0.0,
#  'srkncmk': 0.0,
#  'avmelihdemirer': 0.0,
#  'koinsaati': 0.0,
#  'iyisaplayan': 0.0,
#  'ornek01h': 0.0,
#  'cumunivkurumsal': 0.0,
#  'gercekmuhabir': 0.0,
#  'thatsmyrain': 0.0,
#  'onlywayrevolut': 0.0,
#  'baydno': 0.0,
#  'burcu21414482': 1.0,
#  'ehmania1': 0.0,
#  'sevil_atasoy': 0.0,
#  'da_lalis': 0.0,
#  'livelyforbes': 0.0,
#  'milletvekilic': 0.0,
#  'llamahwang14': 0.0,
#  'gunelabbass': 0.0,
#  'fezzaloji': 0.0,
#  'murat11649766': 1.0,
#  'arsendef': 0.0,
#  'bezrhn': 0.0,
#  'nureyluel': 0.0,
#  'gllisee': 0.0,
#  'pekk69864980': 0.0,
#  'hanfenndii': 0.0,
#  'nursukabblan': 0.0,
#  'gumit841': 0.0,
#  'tan_semsi': 0.0,
#  'genclikplatfrm': 0.0,
#  'kifayetnc': 0.0,
#  'kunwakul': 0.0,
#  'atam0606': 0.0,
#  'betuldikennn01': 0.0,
#  'bahadirsabir': 0.0,
#  'with_hoope': 0.0,
#  'mouyanal': 0.0,
#  'yusufelmas': 0.0,
#  'haberin_ozetii': 0.0,
#  'asyalhabib': 0.0,
#  'velitesemissary': 0.0,
#  'irmkcy_11': 0.0,
#  '10sefa1903': 0.0,
#  'maryandgringo': 0.0,
#  'gizemlax': 0.0,
#  'alanar42327715': 1.0,
#  'eskileriattim': 0.0,
#  '__benbilmem__': 0.0,
#  '10zekeriya': 1.0,
#  'fzt1986': 0.0,
#  'ali_oztunc': 0.0,
#  'kartal28asil': 0.0,
#  'mdnhakann': 0.0,
#  'sekipdadas': 0.0,
#  'selim09219758': 0.0,
#  'bakitemurlenk': 0.0,
#  'isaozguness': 0.0,
#  'salimkaugama': 0.0,
#  'mtolg33': 0.0,
#  'klavuzukargaa': 0.0,
#  'emindin61738283': 1.0,
#  'juniorcivciv': 0.0,
#  'aparachiqui': 0.0,
#  'sadebirinsann': 0.0,
#  'drsevgisaat': 0.0,
#  'baristurkdogdu': 0.0,
#  '1923zetazeus': 0.0,
#  'hypex_emre': 0.0,
#  'delico93742981': 0.0,
#  'skender33766338': 0.0,
#  'nilcakirr': 0.0,
#  'kadirseymen41': 0.0,
#  'jigola781': 0.0,
#  'tuba63352089': 0.0,
#  'muratkocak1806': 0.0,
#  'gurbanaslan': 0.0,
#  'beytbaba': 0.0,
#  'fevzigenc12': 0.0,
#  'semihasattler': 0.0,
#  'mehmetbir4284': 0.0,
#  'elfidamm21': 0.0,
#  'selimgultekn51': 0.0,
#  'alibabacan': 0.0,
#  'vtimidir': 1.0,
#  'ucmagayolculuk': 0.0,
#  'anbaksi': 0.0,
#  'habibet12': 1.0,
#  'elcapitanojk': 0.0,
#  'malsfbittik': 0.0,
#  'cakmatraderr': 0.0,
#  'tuncayopcin': 0.0,
#  'muratt16284598': 0.0,
#  'ahadinas': 0.0,
#  'senatavsan4': 0.0,
#  'hasanemrekaya14': 1.0,
#  'dinginavukat': 0.0,
#  'gelecekcat': 0.0,
#  'kanbaroglu': 0.0,
#  'murblues': 0.0,
#  'sphyldz': 0.0,
#  'kelebek43287554': 1.0,
#  'alemdaroglu65': 0.0,
#  'seks8prens': 0.0,
#  'gnluk_burc': 0.0,
#  'venicebitchn': 0.0,
#  'kamboyal1296': 0.0,
#  'caramelacat': 0.0,
#  'selami_askin_': 0.0,
#  'gfbdilekkaya': 0.0,
#  'mustafa38119280': 0.0,
#  'burakdaricili': 0.0,
#  'yaylaerdem': 1.0,
#  'selin4121': 0.0,
#  'habersecimi': 1.0,
#  'saridagrahim': 0.0,
#  'ofmx59': 0.0,
#  'erincbilican': 0.0,
#  'erbaymercan': 0.0,
#  'necibe2020': 1.0,
#  'gulrumeysa': 0.0,
#  'tba2733': 0.0,
#  'yoongssae': 0.0,
#  'ferahfands': 0.0,
#  'fikricik': 0.0,
#  'cuckolderkegim': 0.0,
#  'allahuekber1453': 1.0,
#  'ilgimcann': 0.0,
#  'magdurbedellii': 0.0,
#  'for_justice35': 0.0,
#  'cgumrukcu06': 0.0,
#  'kasapoglu': 0.0,
#  'klvzemr': 0.0,
#  'suat10679865': 1.0,
#  'kemalettinbigec': 0.0,
#  'nediosun00': 0.0,
#  'hlya655778111': 1.0,
#  'yusufopak': 0.0,
#  'leevenicebitch': 0.0,
#  'redlion98': 0.0,
#  ...}

# %% [markdown]
# # PREPARE SUBMISSION

# %% [markdown]
# You will need to submit exact same file produced by using the following code. Any deviation from the desired format willbe marked as 0.

# %%
# Explain your approach

data_explanations = '''
To strengthen our training data, we concatenated all annotation files (from each group member) with the main training datasets.
Since the given prediction test dataset can not be verified (no labels provided), we divided our dataset into two subsets of 80% allocated for training and 20% set aside for testing, in order to evaluate the performance of our machine learning models.
'''

feature_explanations = '''
For feature extraction process, we discussed our annotation methodologies for both isPolitical and isBot parts.
Based on our common approaches, we selected the most useful features which were not included in the base template model.

created_at = the account's creation date.
since: it refers to the time passed from date that the account has been created 
user_geo_enabled : it is 1 if the user enabled his location.
user_verified : it refers to whether the account has verified by Twitter or not. 
count_digits : It refers to the amount of digits that exist in a username.
user_protected: It is 1 if the user has a private account.
user_followers_count: the number of followers that a user has.
user_friends_count: the number of people that the user is following.
description_len: the number of characters of the bio (description) of the user. 
user_tweet_count: the number of tweets that the user tweeted.
user_fav_count: the number of tweets that the user favorited.
average_tweet: the average amount of tweet that user tweeted since he joined to Twitter.
average_fav: the average amount of tweets that user favorited since he joined to Twitter.
followers_to_all_ratio: followers / (followers + friends)
is_reply: it indicates whether the tweet is a reply to another tweet.
replied_username: the username of the tweet which is replied.
tweet_length: the lenght of the tweet.
punctuation: the number of punctuation marks.

and additionally, we added more keywords to the political entities list.
'''

model_explanations = '''
In our modelling we had used following modelling methodologies and compared their Accuracy and MSE scores to determine best model.
GridSearch Cross Validation is applied to XGBoost, AdaBoost, DecisionTree to find best hyperparameter values.
Standard scaling is applied to all numerical values (normalization).


Here our tested Models 
    Decision Tree Accuracy: MSE:
    Random Forest Accuracy: MSE:
    Logistic Regression Accuracy: MSE:
    XGBoost Accuracy: MSE:
    AdaBoost Accuracy: MSE:
    LGBM Accuracy: MSE:
    NLP-BERT Accuracy: 0.85 MSE: 0.154
    KNN (K-Nearest Neighbors)
    Stacking Classifier
    Soft Voting Classifier
    Gaussian Naive Bayes 
    
We are planning to utilize NPL-BERT model (NLP, encoded-base tranformer model-BERT) for isPolitical part in the next round,
and CNN for the isBot part.


For Bot Test We used 

For Political Test We used 
'''

additional_explanations = '''
It seems that improving the quality and the quantity of the political entity list, increases the accuracy rate we have obtained significantly.
Also the adding the annotation files to the training set is something we have brain-stormed.
'''

# %%
ROUND = 1
STUDENT_ID = 26772

# %%
import json
 
# Opening JSON file
with open(DATA_PATH+'dict.json') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'1593649159009099777': 1.0,
#  '1367571642604544000': 0.0,
#  '1589993032975544320': 1.0,
#  '1565312596135354373': 1.0,
#  '1388235183653011462': 0.0,
#  '1592120408073203712': 1.0,
#  '1439547067337256967': 0.0,
#  '1597274845381029888': 1.0,
#  '1586021183958704128': 1.0,
#  '1356926480605982728': 0.0,
#  '1595357036925026306': 1.0,
#  '1585766233491886081': 1.0,
#  '1595871258985615361': 1.0,
#  '1352635736537882629': 0.0,
#  '1583477966373543936': 1.0,
#  '1564926450096013313': 0.0,
#  '1585634359612420101': 1.0,
#  '1384499047390658560': 0.0,
#  '1596583748669419521': 0.0,
#  '1391681495622995971': 0.0,
#  '1365710259549966339': 0.0,
#  '1590673118397624323': 1.0,
#  '1389951943343316995': 0.0,
#  '1407921226656280580': 0.0,
#  '1452348722810138646': 1.0,
#  '1597256187325878273': 1.0,
#  '1595829502021623812': 1.0,
#  '1579408398894137344': 1.0,
#  '1570758749606019073': 1.0,
#  '1366091745772077058': 0.0,
#  '1596233602886701057': 1.0,
#  '1584922292127256577': 1.0,
#  '1586279180983042050': 1.0,
#  '1399687111234756612': 0.0,
#  '1363226564683522051': 0.0,
#  '1596978345560150016': 1.0,
#  '1593686506622914560': 1.0,
#  '1424467918679597060': 0.0,
#  '1350478535954198530': 0.0,
#  '1375408516337389577': 0.0,
#  '1363883546637701121': 0.0,
#  '1547698793704960002': 1.0,
#  '1584612611160625152': 1.0,
#  '1593653522624643072': 1.0,
#  '1586647493152047104': 1.0,
#  '1561321365805883393': 1.0,
#  '1353277780465770502': 0.0,
#  '1441304592713601026': 0.0,
#  '1594271235260747776': 1.0,
#  '1595049063837229056': 0.0,
#  '1583499914990202880': 1.0,
#  '1590726812362952704': 1.0,
#  '1594813701127041024': 1.0,
#  '1588263918895394821': 1.0,
#  '1425899368788398085': 0.0,
#  '1547256104844988428': 1.0,
#  '1412471406449860611': 0.0,
#  '1591130555424571393': 1.0,
#  '1397627284757131268': 0.0,
#  '1546261307086848001': 1.0,
#  '1358374543912484872': 1.0,
#  '1387829690510057472': 0.0,
#  '1370770949889490947': 1.0,
#  '1560268603596779523': 1.0,
#  '1582579835553320961': 1.0,
#  '1396783902526693380': 0.0,
#  '1561345101305085957': 1.0,
#  '1596412648153059328': 1.0,
#  '1441844889134583808': 0.0,
#  '1417510101041176580': 1.0,
#  '1416778304452009984': 1.0,
#  '1598051085003857921': 0.0,
#  '1352726914398613504': 0.0,
#  '1380175362978680832': 0.0,
#  '1446449109997604865': 0.0,
#  '1366832249287622659': 0.0,
#  '1583368510306103296': 1.0,
#  '1592602720569286656': 1.0,
#  '1584540464224808960': 1.0,
#  '1561985072722583554': 1.0,
#  '1352717957911220226': 0.0,
#  '1579559691965038594': 1.0,
#  '1592017532151803904': 1.0,
#  '1347649378903875584': 0.0,
#  '1593110096045019136': 1.0,
#  '1595738052990828544': 1.0,
#  '1579854640392601600': 1.0,
#  '1596260609242595328': 1.0,
#  '1588193781031047168': 1.0,
#  '1595518151009124352': 1.0,
#  '1586093449287434240': 1.0,
#  '1586436277234114561': 1.0,
#  '1588321676323950593': 1.0,
#  '1544186612246003713': 1.0,
#  '1593561913761452032': 1.0,
#  '1400907711148089348': 0.0,
#  ...}

# %%
predictions = {
    'round': ROUND,
    'student_id': STUDENT_ID,
    'user_predictions': modelPredUser,
    'tweet_predictions': data,
    'explanations': {
        'data': data_explanations,
        'feature': feature_explanations,
        'model': model_explanations,
        'other': additional_explanations,
    }
}


with open('predictions-{}_round{}.json'.format(STUDENT_ID, ROUND), 'w') as fl:
    fl.write(json.dumps(predictions, indent=4))

# %%
# Test your submission file

submission = json.load(open('predictions-{}_round{}.json'.format(STUDENT_ID, ROUND), 'r'))
submission
# Out:
# {'round': 1,
#  'student_id': 26772,
#  'user_predictions': {'nedenburdaysam': 0.0,
#   'biologselim': 0.0,
#   'alaraaynncnm': 0.0,
#   '_sydneycarton_': 0.0,
#   'denizlihabercom': 0.0,
#   'burakerbaychp': 0.0,
#   'mustafaarst': 0.0,
#   'mvnez': 0.0,
#   'qara118': 0.0,
#   'alpar_kaan': 0.0,
#   'farukhalit2': 0.0,
#   'haf_zhan': 0.0,
#   'harlunoshi': 0.0,
#   'heritagepaix': 0.0,
#   '37baho37': 0.0,
#   'tamerduran_1': 0.0,
#   'donkisotumsu': 0.0,
#   'nuranwolf': 0.0,
#   'politikgundem': 0.0,
#   'isakethudax': 0.0,
#   'ilaydejaneiro': 0.0,
#   'gendenmukatol': 0.0,
#   '1905anason': 0.0,
#   'eraydurgut03': 0.0,
#   'dasiskein': 0.0,
#   'mett_1907': 0.0,
#   'semihyeteer': 0.0,
#   'haberinyokcokk': 0.0,
#   'meleky_ozaydin': 0.0,
#   'han34nesli': 0.0,
#   'bilobi4': 0.0,
#   'berkeduranovic': 0.0,
#   'cagdasadim': 0.0,
#   'merabalare': 0.0,
#   'sevdaac72373936': 1.0,
#   '21gramlife1': 0.0,
#   'cakan0_': 0.0,
#   'oguzksalici': 0.0,
#   'emre_caliskann': 0.0,
#   'mehmet07454846': 0.0,
#   'lifegs': 0.0,
#   'begumkarabeyx': 0.0,
#   'avutulan': 0.0,
#   'imamgibiimam': 0.0,
#   'durdane52': 0.0,
#   'radyotrafik35': 0.0,
#   'rk_ozanyali': 0.0,
#   'uykusuz75': 0.0,
#   'goksubayy': 0.0,
#   'ilgihaber': 0.0,
#   'samobisus': 0.0,
#   'iddaaalkc': 0.0,
#   'nnnccdd': 0.0,
#   'iskndr0935': 0.0,
#   'gknilg': 0.0,
#   '_simurg1_': 0.0,
#   'lasmananaskiss': 0.0,
#   'berhanataoglu': 0.0,
#   'alicemalakgl1': 0.0,
#   'denizaydemirchp': 0.0,
#   'sevdesensoz': 0.0,
#   'uortaogretim': 0.0,
#   'matiasemilio19': 0.0,
#   'furkanakinbjk': 0.0,
#   'altinhakan': 0.0,
#   'chpfotograf': 0.0,
#   'ibuzgan': 0.0,
#   'snurgo': 0.0,
#   'selincivali': 0.0,
#   'akgencbagcilar': 0.0,
#   'tayyarturkes': 0.0,
#   'nefiorii': 0.0,
#   'turan_3460_': 0.0,
#   'yavuztellioglu': 0.0,
#   'feyyzatemeltas': 0.0,
#   'dr_sozdemir': 0.0,
#   'gulden_girgin': 0.0,
#   'n11comdestek': 0.0,
#   'vkooktime': 0.0,
#   'mikailavc13': 0.0,
#   'maveravakfi': 0.0,
#   'meftuniyet': 0.0,
#   'aygultoni': 0.0,
#   'melihaakyol77': 0.0,
#   'asikkutluserkan': 0.0,
#   'yorgun_anney': 0.0,
#   'ozkancvs': 0.0,
#   'bakhelebak': 0.0,
#   'bahargelecek123': 0.0,
#   'muzaffermuzzy49': 0.0,
#   'qquazarr': 0.0,
#   'zgrlknegzel1': 0.0,
#   'primiti16830778': 0.0,
#   'mertgng49257897': 0.0,
#   'aydan_gedik6': 1.0,
#   'maltepeakparti': 0.0,
#   'szqeswa': 0.0,
#   'isaal1': 0.0,
#   'safaktun1': 0.0,
#   'hikimse10392188': 0.0,
#   'benigermeeyin': 0.0,
#   'cakirkeyif1903': 0.0,
#   'mnurpol': 0.0,
#   'siddeteson2': 0.0,
#   'coffelers17': 0.0,
#   'tubiiiissss': 0.0,
#   'binnazatma': 0.0,
#   'aysegul2712': 0.0,
#   'cerrahdrmurat': 0.0,
#   'mustafapolatist': 0.0,
#   'recepgnt': 0.0,
#   'tduygukultur': 0.0,
#   'troublebuse': 0.0,
#   'arzuerdemdb': 0.0,
#   'yinemihakkli': 0.0,
#   'alioktaydereci': 0.0,
#   'mvp_1030': 0.0,
#   'mudiclk01': 0.0,
#   'dhainternet': 0.0,
#   'birsen_birgul': 0.0,
#   'vbozkurt55': 0.0,
#   'murat_kurum': 0.0,
#   'tinywangxian': 0.0,
#   'radtek43770356': 0.0,
#   'ssairaoml': 0.0,
#   'daysoldier': 0.0,
#   'ldtasdelen': 0.0,
#   'trtradyo1': 0.0,
#   'free_archi': 0.0,
#   'resmihaberler': 0.0,
#   'hasansonmez77': 0.0,
#   'emirssenol': 0.0,
#   'eyzira': 0.0,
#   'globalkripto1': 0.0,
#   'umutnimetatas': 0.0,
#   'bulentsanverchp': 0.0,
#   'vidacitigris': 0.0,
#   'noluyoruya': 0.0,
#   'bisakinol_1881': 0.0,
#   'sevalkayan01': 0.0,
#   'nimetssevimtr': 1.0,
#   'hasankocatepe26': 0.0,
#   'f_dont': 0.0,
#   'valisu31': 0.0,
#   'frat22880933': 0.0,
#   'haber_ortami': 1.0,
#   'eminegkrr': 0.0,
#   'taibosman': 0.0,
#   'nkomakhos': 0.0,
#   'alipeker1903': 0.0,
#   'kazimsarican': 0.0,
#   'pyrzca': 0.0,
#   'turkan__ay': 0.0,
#   'sametsettt': 0.0,
#   'onurkirac01': 0.0,
#   'oakziner': 0.0,
#   'kingofthebjk': 0.0,
#   '__ebedmuddet__': 0.0,
#   'aydoganali68': 0.0,
#   'umtbaykal': 0.0,
#   'endersarilacvrt': 0.0,
#   'semihates43': 0.0,
#   'ilkmp3': 0.0,
#   'babai1235': 0.0,
#   'nursse_hemsire': 0.0,
#   'hamitpicak46': 0.0,
#   'captzulu737': 0.0,
#   'refikdartici': 0.0,
#   'aliefeuygun': 0.0,
#   'ugur_tarhan': 0.0,
#   'yiyotekin': 0.0,
#   'ludwigplanckk': 0.0,
#   '34feyzu': 0.0,
#   'firatyurdakul': 0.0,
#   'rserkant': 0.0,
#   'serkanyardim': 0.0,
#   'openaichattr': 0.0,
#   'ay47729837': 0.0,
#   'tbatmaz2': 0.0,
#   'yavuzz65': 0.0,
#   'starlightd0': 0.0,
#   'alfredofoot': 0.0,
#   'yagclut': 1.0,
#   'gezsed': 0.0,
#   'nurdino7': 0.0,
#   'iyusufturanli': 0.0,
#   'tvnet': 0.0,
#   'muzafferburann': 0.0,
#   'muziksever00': 0.0,
#   'aveonjcom': 0.0,
#   'utikitiki': 0.0,
#   'bugan_hac': 0.0,
#   'gloryjadey': 0.0,
#   'zaferisik016': 0.0,
#   'semioticus': 0.0,
#   'dumendenhaydar': 0.0,
#   'ykiranoglu': 0.0,
#   'furkicanab': 0.0,
#   'fatihya45929940': 0.0,
#   'hsnkaratas1907': 0.0,
#   'macovskiii': 0.0,
#   'uerdovan': 0.0,
#   'berat92266271': 1.0,
#   'kvseryyla': 0.0,
#   'waspazy': 0.0,
#   'eneskaanylmz': 0.0,
#   'volkanipek32': 0.0,
#   'ezgiekincelik1': 0.0,
#   'turizmgazete': 0.0,
#   'mer06666': 1.0,
#   'su_pinari': 0.0,
#   'denisinbiri': 0.0,
#   '_adnansaruhan_': 0.0,
#   'timbooth75': 0.0,
#   'mustafhaaaa': 0.0,
#   'ossurukboceki': 0.0,
#   'yunusbozkuurt': 0.0,
#   'aksakal_memet': 0.0,
#   'iyiozgurozyurt': 0.0,
#   'isa_ozguller': 0.0,
#   'baraan56': 0.0,
#   'aftiel86': 0.0,
#   'mygazeteantalya': 0.0,
#   'cemile_cetiner': 0.0,
#   'mehmetmert70': 0.0,
#   'ulayoezer': 0.0,
#   'gokcegokcen_': 0.0,
#   'aaltuntas70': 0.0,
#   'umayy1907': 0.0,
#   'siyaaydin': 0.0,
#   'v1ens14': 0.0,
#   'samueljsdv': 1.0,
#   'chpuskgenclik': 0.0,
#   'arpacikcihat': 0.0,
#   'kksalseyfullah': 0.0,
#   'miirac0909': 0.0,
#   'alicecrn': 0.0,
#   'ozleemcelk': 0.0,
#   'avemrekptnoglu': 0.0,
#   'mehmetburgac1': 0.0,
#   'ahmetayhan99': 0.0,
#   'osmanakgul29': 0.0,
#   'yusufberk06': 0.0,
#   'hibakkus': 0.0,
#   'tallman93409915': 0.0,
#   'hektor5734': 0.0,
#   'isimsizisim123': 0.0,
#   'sudekafal': 0.0,
#   'uzunnman': 0.0,
#   'emotivasyon': 0.0,
#   'alimutum1964': 0.0,
#   'asliarslaan': 0.0,
#   'mustafa_destici': 0.0,
#   'savunmasanayist': 0.0,
#   'prenses_show': 1.0,
#   'foamofthedaze': 0.0,
#   'osman_aygunn': 0.0,
#   'canernevermind': 0.0,
#   'yalcingg': 0.0,
#   'gundemedairhs': 0.0,
#   'birkomikpanda': 0.0,
#   'tolgahankaya0': 1.0,
#   'iamcansun': 0.0,
#   'hseyink42305996': 0.0,
#   'enastaenistera': 0.0,
#   'mminbicil2': 0.0,
#   'sceleboglu': 0.0,
#   'gokhanmirall': 0.0,
#   'ibrahimkoray28': 0.0,
#   'ayemyasin': 0.0,
#   'kardii2424': 0.0,
#   'nurkanmaz2': 0.0,
#   'imeratarot': 0.0,
#   'aryaaryastark11': 0.0,
#   'abetulkayahan': 0.0,
#   'enhakikimursid': 0.0,
#   'celebimehmeta': 0.0,
#   'erenicooo34': 0.0,
#   'huseyin14330438': 0.0,
#   'agdtv': 0.0,
#   'azatepe': 0.0,
#   'msen5885': 0.0,
#   'lebron2_king': 0.0,
#   'nesrinaras141': 1.0,
#   'muratzaknc1': 0.0,
#   'mesutmustafaak2': 0.0,
#   'ysametiscii': 0.0,
#   'muallarenksiz': 0.0,
#   'restlessschild': 0.0,
#   'avmehmetozkan1': 0.0,
#   'aykutsafakkayaa': 0.0,
#   'hatiec1209': 0.0,
#   'nurhayatesmaa': 1.0,
#   'murathanmhp': 0.0,
#   'seeutmrrw': 0.0,
#   '8lampardd': 0.0,
#   'kaan_blky': 0.0,
#   'cicek321471': 0.0,
#   'smailorak10': 0.0,
#   'tplgll': 1.0,
#   'ezo05264399': 1.0,
#   'bl4ckp1nk97': 0.0,
#   'izmilli19': 0.0,
#   'drmetinilhan40': 0.0,
#   'tubataserr': 0.0,
#   'kaanboz10993308': 1.0,
#   'boragulpinar': 0.0,
#   'haberinizcomtr': 0.0,
#   'tekirdaghatice': 1.0,
#   'm_songulalp': 0.0,
#   'almilapars2': 0.0,
#   'yasinucantr': 0.0,
#   'tmsymustafa': 0.0,
#   'iyiamanedenyani': 0.0,
#   'cengiz1bey': 0.0,
#   'tmrosmanagaoglu': 0.0,
#   'brcukocaa': 0.0,
#   'mustafa_yalcin2': 0.0,
#   'hanifekrcdemir': 0.0,
#   'aryaates10': 1.0,
#   'd3n1z1n_k1z1': 0.0,
#   'senidesavunurum': 0.0,
#   'birarmaugrunaa': 0.0,
#   'emrahadakli': 0.0,
#   'adige_turan': 0.0,
#   'tknnnur': 0.0,
#   'knstntndeluu': 0.0,
#   'dilekkat1': 1.0,
#   'rdvntrkylmz': 0.0,
#   'izelbydn': 0.0,
#   'sevilaynalbant1': 0.0,
#   'bilgekazan02': 0.0,
#   'bizesoruntv': 0.0,
#   'feydem003': 1.0,
#   'bkrhly0803': 0.0,
#   'alleynaa16': 0.0,
#   'osanmaz_kaya': 0.0,
#   'sunflower1823': 0.0,
#   'kwmitchi': 0.0,
#   'muratdu68243139': 0.0,
#   'm_tumer': 0.0,
#   '01_murat_80': 0.0,
#   'melike1234567': 0.0,
#   'tribunnsozluk': 0.0,
#   'j_j_o_10': 0.0,
#   'baliskonuz': 0.0,
#   'ozantur33802030': 0.0,
#   'thelady_mi': 0.0,
#   'oncesiwesonrasi': 1.0,
#   'sunasefer': 0.0,
#   'drosedawson_': 0.0,
#   'akilfikirparti': 0.0,
#   'laylabesiroglu': 0.0,
#   'ansuh1995': 1.0,
#   'sleyman59570757': 1.0,
#   'kocagolali': 0.0,
#   'mhmettedebiyat': 0.0,
#   'mustafa043yedek': 0.0,
#   'ylmzrmz': 0.0,
#   'nurluv1': 1.0,
#   'mhmt_dnmez': 0.0,
#   'isilozcan434': 1.0,
#   'karizma7583_': 0.0,
#   'muammergokcin': 0.0,
#   '1mirzabey': 0.0,
#   'hln_sbs94': 0.0,
#   'chpyemevzu': 0.0,
#   'stajzedenur': 1.0,
#   'socarofficial': 0.0,
#   'smeyye54030601': 1.0,
#   'mdogan80': 1.0,
#   'hasanlal18': 0.0,
#   'aynurr82444477': 0.0,
#   'engindalbast': 0.0,
#   'cevapsiztweet': 0.0,
#   'yuzlasma': 1.0,
#   'vethekbusra': 0.0,
#   'yilmaz_dagdelen': 0.0,
#   'cybermigren': 0.0,
#   'ayyldz38106604': 1.0,
#   'secimlegeldik': 0.0,
#   'hiciiknoktasi': 0.0,
#   'hfzfehmitufan': 0.0,
#   'edinrose5': 0.0,
#   'harunzk45625173': 1.0,
#   'rt_sag1': 1.0,
#   'nesfrit1': 0.0,
#   'meraltan_': 0.0,
#   'feedanhsynli': 0.0,
#   'cuvalogluberkay': 0.0,
#   'turan5801': 0.0,
#   'kimyacibaba1': 0.0,
#   'oxlade25': 0.0,
#   'dorarafa': 0.0,
#   'aydinvaliligi': 0.0,
#   'sevgierol759': 0.0,
#   'deplasmancom': 0.0,
#   'kellecimehmet58': 0.0,
#   'merym2y': 0.0,
#   'mrtkaan5': 0.0,
#   'eminmalazgirt': 0.0,
#   'dilekreelforex': 0.0,
#   'abbas0784': 0.0,
#   'yildirimoztug': 0.0,
#   'gracenewbie': 0.0,
#   'f_ratdemirci': 1.0,
#   'nebi_arda_': 0.0,
#   'eray91576993': 0.0,
#   'meyaschoice': 0.0,
#   'reeltemizlik1': 0.0,
#   'supertolkstolk': 0.0,
#   'bugraa_hann': 0.0,
#   'ishak5334': 0.0,
#   'blueberyboi': 0.0,
#   'malefiziii': 0.0,
#   '81_karacahil': 0.0,
#   'txfrtdy': 1.0,
#   'ewremmm52': 0.0,
#   'bayrakvatan34': 0.0,
#   'bravextr': 0.0,
#   'jeneriklikpas': 0.0,
#   'nejla188136991': 1.0,
#   'somewhere9s': 0.0,
#   'izim62': 0.0,
#   'kayanadnah': 1.0,
#   'hayri8383': 1.0,
#   'demirness02': 1.0,
#   'mrynr4': 0.0,
#   'minikbelanzz': 0.0,
#   'hasan_killik': 0.0,
#   'tukul46': 0.0,
#   'wolfofwst1907': 0.0,
#   'ccbiazin': 0.0,
#   'ozenhlc': 0.0,
#   'yektaorkuncelik': 0.0,
#   'ayhaneroglu14': 1.0,
#   'ensdndr1': 0.0,
#   'maynameserpil': 0.0,
#   'marti141216': 0.0,
#   'nurayshine': 0.0,
#   'mustafayel59': 0.0,
#   'serdaraydinnn': 0.0,
#   'papatya84595001': 1.0,
#   'cazhareketi': 0.0,
#   'myildirim_06': 0.0,
#   'inleyerek31': 0.0,
#   'hicran33880494': 0.0,
#   'adem_ahmet': 1.0,
#   'iyi_kus': 0.0,
#   'arikanmucahit32': 0.0,
#   'm_cicekdagi32': 0.0,
#   '44hakan34': 0.0,
#   'ers25936353': 1.0,
#   'yalan__zaman': 0.0,
#   'erbaturdeniz': 0.0,
#   'veyseldayan65': 0.0,
#   'sencerbeyyyy': 1.0,
#   'akavutoglu': 0.0,
#   'tahsin87664169': 0.0,
#   'cansufcbmg': 0.0,
#   'bora_ares': 0.0,
#   'alkanokuducu': 0.0,
#   '18eren': 0.0,
#   'aysesibelersoy': 0.0,
#   's010335835191': 0.0,
#   'hilcoban': 0.0,
#   'muhyittinaltun1': 0.0,
#   'halukkunuk1970': 0.0,
#   'ua_mehmety_gs': 0.0,
#   'nmmachiavelli': 0.0,
#   'neziraltan4': 1.0,
#   'murat03814297': 0.0,
#   'difuruz': 0.0,
#   'wineteamo': 1.0,
#   'seldaakgun36': 0.0,
#   'baris01451930': 0.0,
#   'suathayri8': 0.0,
#   'ayea98437004': 1.0,
#   'sensoyle_1': 0.0,
#   'ejderbit': 0.0,
#   'guraytturkoglu': 0.0,
#   'turguttunc34': 0.0,
#   'emrksk81': 1.0,
#   'kocakvahit': 0.0,
#   'fercu22': 0.0,
#   'askerr01': 1.0,
#   'zeyirsoylu4': 0.0,
#   'liderimrte2023': 1.0,
#   'semoswebster': 0.0,
#   'ddionysos_s': 0.0,
#   'lutfikasikci': 0.0,
#   'turk_texas': 0.0,
#   'nalcieslem': 0.0,
#   'havanur_3442': 0.0,
#   'tenkyuverima': 0.0,
#   'bek_mirzo23': 0.0,
#   'rd3622': 0.0,
#   'muhammetummunfs': 1.0,
#   'bsmedya': 0.0,
#   'seyyah2011': 0.0,
#   'selcuk64493163': 0.0,
#   'myzc88': 0.0,
#   'esgaldhor': 0.0,
#   'rego97687151': 0.0,
#   'elbasrisenn': 0.0,
#   'ali86626921': 0.0,
#   'sekulerme': 0.0,
#   'jiskenderoglu': 0.0,
#   'demir342734': 0.0,
#   'lanetfederal9': 0.0,
#   'marlboroliightt': 0.0,
#   'rakisaati': 0.0,
#   'ferhandemir25': 1.0,
#   'fuatoze2': 0.0,
#   'muzaffe1971': 0.0,
#   'madak71': 0.0,
#   'asparagas08': 0.0,
#   'miyaavvs': 0.0,
#   'gultenbacaks': 1.0,
#   'hera_74': 0.0,
#   'targetvienna': 0.0,
#   'mustafademirok5': 1.0,
#   'eminedali': 0.0,
#   'vdreamergrey_': 0.0,
#   'zcan43809267': 0.0,
#   '7reporter': 0.0,
#   'mhmtcnkrgl1': 0.0,
#   'hakanarol': 0.0,
#   'turan_ordusu53': 1.0,
#   'damllasenn': 0.0,
#   'batcao': 0.0,
#   'qaa52815672': 0.0,
#   'myruh34': 0.0,
#   'nurcugdso': 0.0,
#   'ayenur656431111': 0.0,
#   'melimisss': 0.0,
#   'dgnalirza': 0.0,
#   'hseyinyzbaolu31': 0.0,
#   'akgenclikmus': 0.0,
#   'redrojo76665196': 0.0,
#   'gokseelgok': 0.0,
#   'sahabettin_sebe': 0.0,
#   'umutisigiii': 0.0,
#   'sahsenem_s': 0.0,
#   'leonamelzo': 0.0,
#   'mkarakuzu3': 1.0,
#   'excalibur34tr': 0.0,
#   'mercedesbeyz': 0.0,
#   'haticedemirer13': 0.0,
#   'nilovalii': 0.0,
#   'gurbuzyurdanur': 0.0,
#   'ismailozkantv': 0.0,
#   '__yel__iz__': 0.0,
#   'furkandenizv': 0.0,
#   'gabymenta': 0.0,
#   'plutonluur_': 0.0,
#   'ahmet42359666': 0.0,
#   'samettdonmezz': 0.0,
#   'mehmet_arzu21': 0.0,
#   'chicoofresaa': 0.0,
#   'polatgokhan72': 0.0,
#   'uuttkuuu1': 0.0,
#   'suskun_ca': 0.0,
#   'pelinso19646937': 0.0,
#   'skaantopaloglu': 0.0,
#   'yusufozel50': 0.0,
#   'sadecekaravaris': 0.0,
#   'mehmete23916590': 0.0,
#   'ertugrulhasa': 1.0,
#   'ebuhurma_bin71': 0.0,
#   'aalparslandogan': 0.0,
#   '4646kkk': 0.0,
#   'hasan48527150': 1.0,
#   'mrpetit03': 0.0,
#   'yakup_tac': 1.0,
#   'aygannizamettin': 0.0,
#   'akiffydn54': 0.0,
#   'huseyindagteki8': 0.0,
#   '_ys33': 0.0,
#   'kapakedebiyati': 0.0,
#   'psychedelicmega': 0.0,
#   'anittepemah': 1.0,
#   'eruilivatar': 0.0,
#   'rahan78614563': 0.0,
#   'alsacselahattin': 0.0,
#   'nessybabysi': 0.0,
#   'azizdortler': 0.0,
#   '1903cakmakoglu': 0.0,
#   'neocaesarean': 0.0,
#   'farukel27207281': 1.0,
#   'tckemal59451041': 0.0,
#   'elifhalilsunar': 0.0,
#   'referansgazetes': 0.0,
#   'vodkaliborek': 0.0,
#   'eagleselmann': 0.0,
#   'muazzezkarakuz1': 1.0,
#   'alinuraktas70': 0.0,
#   'analizlerle': 0.0,
#   'xymemyan': 0.0,
#   'serpil69937590': 1.0,
#   'meemoolii07': 0.0,
#   'ucanlarinozguru': 0.0,
#   'temoootemooo1': 0.0,
#   'llbusrra': 0.0,
#   'mihrimahgundogd': 1.0,
#   'ezgii22e': 0.0,
#   'empathy1069': 0.0,
#   'abdullahdmr5234': 0.0,
#   'nenehatun252525': 0.0,
#   '52ellianti': 1.0,
#   '06murat40': 0.0,
#   'muhdsumar': 0.0,
#   'radyolojitgt11': 0.0,
#   '100binatamahak': 1.0,
#   'kuzenraven': 0.0,
#   'herkann': 0.0,
#   '_emel_iskender_': 0.0,
#   'mehmetaktass42': 0.0,
#   'mehmetcalik1903': 0.0,
#   'iyi_psikoloji': 0.0,
#   'rahmikangal8181': 0.0,
#   'ispahaergun': 0.0,
#   'sir_gala': 0.0,
#   'onder_1881': 1.0,
#   'aglamicamaglami': 0.0,
#   'der__en': 1.0,
#   'c_keper': 0.0,
#   'barisustunbas34': 0.0,
#   '81subat': 0.0,
#   'cifri77': 0.0,
#   'phoenixsnm': 0.0,
#   'mehmettoprakk55': 0.0,
#   'aysun_becek': 1.0,
#   'ahmetckarali': 0.0,
#   '123ciklet': 0.0,
#   'akkadinbeykoz': 0.0,
#   'mehvesdemirer': 0.0,
#   'gazetemuz': 0.0,
#   'tevfikozgul': 0.0,
#   'oyablsl': 0.0,
#   'atam02': 0.0,
#   'jamesblacklol': 0.0,
#   'shnhuri': 0.0,
#   'cananyslyrt98': 0.0,
#   'milanbarosizm': 0.0,
#   'y35936059': 1.0,
#   'sungurogiu': 0.0,
#   'ilhan29914305': 1.0,
#   'tbugradayi': 0.0,
#   'muammerelk4': 0.0,
#   'sedefbostan1': 1.0,
#   'yunuserkul9': 1.0,
#   'bouquet_buket': 0.0,
#   'ahmetkurolu1': 0.0,
#   'sofuatar1': 0.0,
#   'duygu44655629': 0.0,
#   'alican69969774': 0.0,
#   'oyumchpye': 0.0,
#   'eliscilik': 0.0,
#   'httopal': 0.0,
#   'akgulhasan62': 0.0,
#   'cevahir_tolga': 0.0,
#   'byunlipsloey': 0.0,
#   'metaverse_promt': 0.0,
#   'rmzsulo': 0.0,
#   'ceredipity': 0.0,
#   'aliyletivitce': 0.0,
#   'erolylmz020': 0.0,
#   'venividiperivi': 0.0,
#   'baharmtumer': 0.0,
#   'cumhuriyetgzt': 0.0,
#   'seyfullahaslan': 0.0,
#   'naobad94': 0.0,
#   'mucellapakdemir': 0.0,
#   'monoclockth': 0.0,
#   'abdullahcinsul1': 1.0,
#   'istinye_yokusu': 0.0,
#   'hakkitaruz': 0.0,
#   'bbpbyrmpsresmi': 0.0,
#   'etkinlikatma': 0.0,
#   'santiagonowcast': 0.0,
#   'bilalhotmailco6': 0.0,
#   'kemalaydomu11': 0.0,
#   'mehmeta17853051': 1.0,
#   'constantinapolx': 0.0,
#   'fuckleroykendal': 0.0,
#   'altanbostanci': 0.0,
#   'nurlu_hnn': 0.0,
#   'mafazannakk': 0.0,
#   'osman5138': 0.0,
#   'nebi_nuh': 0.0,
#   'robingstz': 0.0,
#   '_forever_1903': 0.0,
#   'rebercn': 0.0,
#   'sevgiorc': 1.0,
#   'prvszakrep': 0.0,
#   'metehannn_8': 1.0,
#   'tonygozet': 0.0,
#   'dndr_ztrk': 0.0,
#   'karslan17': 0.0,
#   'yuksekova_m': 0.0,
#   'ahaistebu': 0.0,
#   'seyma_btl_': 0.0,
#   'avhaticeyldz': 0.0,
#   'adinna__': 0.0,
#   'a82317335aslan': 1.0,
#   'bozkurt_dogan1': 0.0,
#   'kyaegunn': 0.0,
#   'epiphanlarity': 0.0,
#   'huseyin_agars': 0.0,
#   'izzet_besevli78': 0.0,
#   'insaneautor': 0.0,
#   'baweraunnehir': 0.0,
#   'zekikar46878782': 1.0,
#   'foraorg': 0.0,
#   'levent28939983': 0.0,
#   'seherbirinciii': 0.0,
#   'muslumbaba25': 0.0,
#   'dniigeria': 0.0,
#   'ahmetdoan011': 0.0,
#   'kerem84242180': 0.0,
#   'fenersonhaber': 0.0,
#   'dedeoglusakir': 0.0,
#   'serseriyimsenle': 0.0,
#   'nisebinciyager': 0.0,
#   'noyanayra': 0.0,
#   'yildirimsamii': 0.0,
#   'muserrefkargi': 0.0,
#   'dipsiz1kuyu7': 0.0,
#   'sevda78899': 1.0,
#   'serhatkozturks': 0.0,
#   'mustafa__kynk': 0.0,
#   'masmakut': 0.0,
#   'koksal87889937': 0.0,
#   'huseyin70502807': 0.0,
#   'kuzey1800': 1.0,
#   'cebrailtemel52': 0.0,
#   'aysen_yldrm_': 0.0,
#   'busraurr': 0.0,
#   'fulyasimsekcakr': 0.0,
#   'cuma06235351': 1.0,
#   'fatihsu145323': 0.0,
#   'timucin3406': 0.0,
#   'darkes_48': 0.0,
#   'ebeamaatanamadi': 0.0,
#   'ismetah04165791': 0.0,
#   'adalethak6': 1.0,
#   'aslankralist': 0.0,
#   'prince__raji': 0.0,
#   'kddrummondnfl': 0.0,
#   'furkanblenterd1': 0.0,
#   'ferhanxyz': 0.0,
#   'zorunlucografya': 0.0,
#   'ddurust2': 0.0,
#   'yazdikanka': 0.0,
#   'songul___2023': 1.0,
#   'irfan_girgin_': 0.0,
#   'ahmetsenal1': 0.0,
#   'hunilisaphiens': 0.0,
#   'promo_togo': 0.0,
#   'memetuar18': 0.0,
#   'gkhan989793831': 0.0,
#   'bbisekreter1': 0.0,
#   '_saituk_': 0.0,
#   'pandoraninkoli': 0.0,
#   'kemalolu6': 0.0,
#   'brahim04798715': 0.0,
#   'serkanksoz': 0.0,
#   'yedinchss': 0.0,
#   'umkumuncuk': 0.0,
#   'adelante_d': 0.0,
#   'maviasi17': 0.0,
#   'huzur098712': 0.0,
#   'kenan_kiran': 0.0,
#   'ozelsakura': 0.0,
#   'mel75801': 0.0,
#   'turktur_ozum': 0.0,
#   'noavasblog': 0.0,
#   'smr_plt_': 0.0,
#   'tr_whitestar': 0.0,
#   'bekirgonenn': 0.0,
#   'sebo_1963': 0.0,
#   'sananelantospik': 0.0,
#   'unalcevikoz': 0.0,
#   'metehansahiiiin': 0.0,
#   'kocdevrim01': 0.0,
#   'turizmhabermrk': 0.0,
#   'magnofrancklin': 0.0,
#   'cagricantopcu': 0.0,
#   'karakus_aylak': 0.0,
#   'jossalove24': 1.0,
#   'eczhatice07': 0.0,
#   'jonginimio': 0.0,
#   'smalylmaz12': 1.0,
#   'alperrustem': 0.0,
#   'korezincom': 0.0,
#   'demetswife': 0.0,
#   'efe25454822': 1.0,
#   'dirwongkarwai': 0.0,
#   'merve_trh93': 0.0,
#   'yenisolukcom': 0.0,
#   'semihsamet1919': 0.0,
#   'anataeus': 1.0,
#   'kemeroglu_ctn': 0.0,
#   'kucukdunyatr': 0.0,
#   'ekobey37': 0.0,
#   'imparator2569': 0.0,
#   'alimahir': 0.0,
#   'politic_tr': 0.0,
#   'oglu_macarl': 0.0,
#   'ismailttpaloglu': 0.0,
#   'edizyil47765465': 0.0,
#   'ozancankemal': 0.0,
#   'hardtoliveya': 0.0,
#   'chilizkolik': 0.0,
#   'm_eminozdemir33': 0.0,
#   'tarihogretmeni6': 1.0,
#   'kazimkarabek5': 0.0,
#   'brkbarbarosoglu': 0.0,
#   'ahmet_oylek': 0.0,
#   'ahfalandunya': 0.0,
#   'fatihkaraveli61': 0.0,
#   'feyselsimsek': 0.0,
#   'kamudaii1': 0.0,
#   'denizzzz1234': 0.0,
#   'nrdnkle': 0.0,
#   'vefakarguvenlik': 1.0,
#   'ayaz043043': 1.0,
#   'gamze06759975': 0.0,
#   'dilek_sozdarrr': 0.0,
#   'kidsnlo': 0.0,
#   'k971689': 0.0,
#   '28ekim1926': 0.0,
#   'birgazetecom': 0.0,
#   'bibercizehra': 0.0,
#   'ademyrtmen': 0.0,
#   'blueandpurple61': 0.0,
#   'msdegngr07': 0.0,
#   'acikistihbarat': 0.0,
#   'agirmanibrahim': 0.0,
#   'meribasgeri': 0.0,
#   'genclikhasan': 0.0,
#   'edebiyatci_96': 1.0,
#   'du35518218duman': 1.0,
#   'ucankuslarxd': 0.0,
#   'yasemin_busrayy': 0.0,
#   'nihatbuyukbayr1': 0.0,
#   'ttaynaralimaa': 0.0,
#   'gaffarmudur34': 0.0,
#   '2020kpss202020': 1.0,
#   'mrscelikbilek': 0.0,
#   'anadoluatesi36': 0.0,
#   'koftianan': 0.0,
#   'krklm': 1.0,
#   'mnreelk1': 1.0,
#   'mimarastr': 0.0,
#   'taseronsa': 1.0,
#   'ifsaci_abi33': 0.0,
#   'sfrsml': 0.0,
#   'denizsuyu61': 0.0,
#   'alban_idris': 0.0,
#   'srkncmk': 0.0,
#   'avmelihdemirer': 0.0,
#   'koinsaati': 0.0,
#   'iyisaplayan': 0.0,
#   'ornek01h': 0.0,
#   'cumunivkurumsal': 0.0,
#   'gercekmuhabir': 0.0,
#   'thatsmyrain': 0.0,
#   'onlywayrevolut': 0.0,
#   'baydno': 0.0,
#   'burcu21414482': 1.0,
#   'ehmania1': 0.0,
#   'sevil_atasoy': 0.0,
#   'da_lalis': 0.0,
#   'livelyforbes': 0.0,
#   'milletvekilic': 0.0,
#   'llamahwang14': 0.0,
#   'gunelabbass': 0.0,
#   'fezzaloji': 0.0,
#   'murat11649766': 1.0,
#   'arsendef': 0.0,
#   'bezrhn': 0.0,
#   'nureyluel': 0.0,
#   'gllisee': 0.0,
#   'pekk69864980': 0.0,
#   'hanfenndii': 0.0,
#   'nursukabblan': 0.0,
#   'gumit841': 0.0,
#   'tan_semsi': 0.0,
#   'genclikplatfrm': 0.0,
#   'kifayetnc': 0.0,
#   'kunwakul': 0.0,
#   'atam0606': 0.0,
#   'betuldikennn01': 0.0,
#   'bahadirsabir': 0.0,
#   'with_hoope': 0.0,
#   'mouyanal': 0.0,
#   'yusufelmas': 0.0,
#   'haberin_ozetii': 0.0,
#   'asyalhabib': 0.0,
#   'velitesemissary': 0.0,
#   'irmkcy_11': 0.0,
#   '10sefa1903': 0.0,
#   'maryandgringo': 0.0,
#   'gizemlax': 0.0,
#   'alanar42327715': 1.0,
#   'eskileriattim': 0.0,
#   '__benbilmem__': 0.0,
#   '10zekeriya': 1.0,
#   'fzt1986': 0.0,
#   'ali_oztunc': 0.0,
#   'kartal28asil': 0.0,
#   'mdnhakann': 0.0,
#   'sekipdadas': 0.0,
#   'selim09219758': 0.0,
#   'bakitemurlenk': 0.0,
#   'isaozguness': 0.0,
#   'salimkaugama': 0.0,
#   'mtolg33': 0.0,
#   'klavuzukargaa': 0.0,
#   'emindin61738283': 1.0,
#   'juniorcivciv': 0.0,
#   'aparachiqui': 0.0,
#   'sadebirinsann': 0.0,
#   'drsevgisaat': 0.0,
#   'baristurkdogdu': 0.0,
#   '1923zetazeus': 0.0,
#   'hypex_emre': 0.0,
#   'delico93742981': 0.0,
#   'skender33766338': 0.0,
#   'nilcakirr': 0.0,
#   'kadirseymen41': 0.0,
#   'jigola781': 0.0,
#   'tuba63352089': 0.0,
#   'muratkocak1806': 0.0,
#   'gurbanaslan': 0.0,
#   'beytbaba': 0.0,
#   'fevzigenc12': 0.0,
#   'semihasattler': 0.0,
#   'mehmetbir4284': 0.0,
#   'elfidamm21': 0.0,
#   'selimgultekn51': 0.0,
#   'alibabacan': 0.0,
#   'vtimidir': 1.0,
#   'ucmagayolculuk': 0.0,
#   'anbaksi': 0.0,
#   'habibet12': 1.0,
#   'elcapitanojk': 0.0,
#   'malsfbittik': 0.0,
#   'cakmatraderr': 0.0,
#   'tuncayopcin': 0.0,
#   'muratt16284598': 0.0,
#   'ahadinas': 0.0,
#   'senatavsan4': 0.0,
#   'hasanemrekaya14': 1.0,
#   'dinginavukat': 0.0,
#   'gelecekcat': 0.0,
#   'kanbaroglu': 0.0,
#   'murblues': 0.0,
#   'sphyldz': 0.0,
#   'kelebek43287554': 1.0,
#   'alemdaroglu65': 0.0,
#   'seks8prens': 0.0,
#   'gnluk_burc': 0.0,
#   'venicebitchn': 0.0,
#   'kamboyal1296': 0.0,
#   'caramelacat': 0.0,
#   'selami_askin_': 0.0,
#   'gfbdilekkaya': 0.0,
#   'mustafa38119280': 0.0,
#   'burakdaricili': 0.0,
#   'yaylaerdem': 1.0,
#   'selin4121': 0.0,
#   'habersecimi': 1.0,
#   'saridagrahim': 0.0,
#   'ofmx59': 0.0,
#   'erincbilican': 0.0,
#   'erbaymercan': 0.0,
#   'necibe2020': 1.0,
#   'gulrumeysa': 0.0,
#   'tba2733': 0.0,
#   'yoongssae': 0.0,
#   '1446449109997604865': 0.0,
#   '1366832249287622659': 0.0,
#   '1583368510306103296': 1.0,
#   '1592602720569286656': 1.0,
#   '1584540464224808960': 1.0,
#   '1561985072722583554': 1.0,
#   '1352717957911220226': 0.0,
#   '1579559691965038594': 1.0,
#   '1592017532151803904': 1.0,
#   '1347649378903875584': 0.0,
#   '1593110096045019136': 1.0,
#   '1595738052990828544': 1.0,
#   '1579854640392601600': 1.0,
#   '1596260609242595328': 1.0,
#   '1588193781031047168': 1.0,
#   '1595518151009124352': 1.0,
#   '1586093449287434240': 1.0,
#   '1586436277234114561': 1.0,
#   '1588321676323950593': 1.0,
#   '1544186612246003713': 1.0,
#   '1593561913761452032': 1.0,
#   '1400907711148089348': 0.0,
#   ...},
#  'explanations': {'data': '\nTo strengthen our training data, we concatenated all annotation files (from each group member) with the main training datasets.\nSince the given prediction test dataset can not be verified (no labels provided), we divided our dataset into two subsets of 80% allocated for training and 20% set aside for testing, in order to evaluate the performance of our machine learning models.\n',
#   'feature': "\nFor feature extraction process, we discussed our annotation methodologies for both isPolitical and isBot parts.\nBased on our common approaches, we selected the most useful features which were not included in the base template model.\n\ncreated_at = the account's creation date.\nsince: it refers to the time passed from date that the account has been created \nuser_geo_enabled : it is 1 if the user enabled his location.\nuser_verified : it refers to whether the account has verified by Twitter or not. \ncount_digits : It refers to the amount of digits that exist in a username.\nuser_protected: It is 1 if the user has a private account.\nuser_followers_count: the number of followers that a user has.\nuser_friends_count: the number of people that the user is following.\ndescription_len: the number of characters of the bio (description) of the user. \nuser_tweet_count: the number of tweets that the user tweeted.\nuser_fav_count: the number of tweets that the user favorited.\naverage_tweet: the average amount of tweet that user tweeted since he joined to Twitter.\naverage_fav: the average amount of tweets that user favorited since he joined to Twitter.\nfollowers_to_all_ratio: followers / (followers + friends)\nis_reply: it indicates whether the tweet is a reply to another tweet.\nreplied_username: the username of the tweet which is replied.\ntweet_length: the lenght of the tweet.\npunctuation: the number of punctuation marks.\n\nand additionally, we added more keywords to the political entities list.\n",
#   'model': '\nIn our modelling we had used following modelling methodologies and compared their Accuracy and MSE scores to determine best model.\nGridSearch Cross Validation is applied to XGBoost, AdaBoost, DecisionTree to find best hyperparameter values.\nStandard scaling is applied to all numerical values (normalization).\n\n\nHere our tested Models \n    Decision Tree Accuracy: MSE:\n    Random Forest Accuracy: MSE:\n    Logistic Regression Accuracy: MSE:\n    XGBoost Accuracy: MSE:\n    AdaBoost Accuracy: MSE:\n    LGBM Accuracy: MSE:\n    NLP-BERT Accuracy: 0.85 MSE: 0.154\n    KNN (K-Nearest Neighbors)\n    Stacking Classifier\n    Soft Voting Classifier\n    Gaussian Naive Bayes \n    \nWe are planning to utilize NPL-BERT model (NLP, encoded-base tranformer model-BERT) for isPolitical part in the next round,\nand CNN for the isBot part.\n\n\nFor Bot Test We used \n\nFor Political Test We used \n',
#   'other': '\nIt seems that improving the quality and the quantity of the political entity list, increases the accuracy rate we have obtained significantly.\nAlso the adding the annotation files to the training set is something we have brain-stormed.\n'}}
